# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import re
from itertools import chain
import glob
import seaborn as sns
import matplotlib.font_manager as font_manager
import seaborn as sns
import matplotlib as mpl
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import scale 
from sklearn import model_selection
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.linear_model import SGDRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMRegressor
from collections import Counter
from pandas import read_csv
from datetime import datetime
from sklearn.metrics import mean_absolute_percentage_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pandas.plotting import register_matplotlib_converters
import warnings
import itertools
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
register_matplotlib_converters()

# %%
sns.set_theme()
mpl.matplotlib_fname()
font_dirs = ['D:\\Software\\Anaconda\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf' ]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
for font_file in font_files:
    font_manager.fontManager.addfont(font_file)
mpl.font_manager._rebuild()
result = font_manager.findfont("Rounded Mplus 1c")
print(result)
mpl.rc('font', family='Rounded Mplus 1c')
# Out:
# D:\Software\Anaconda\Lib\site-packages\matplotlib\mpl-data\fonts\ttf\MPLUSRounded1c-Regular.ttf

# %%
def extract_engine_data (description, list_em):
    engine_model = []
    for e in list_em:
        em_reg = re.findall(r'\b{}-\w+-?\w*\b'.format(e), description)
        if len(em_reg) != 0 :
          em_reg = map(lambda x : x.split('-')[0],em_reg)
#           em_reg = list(set(em_reg)) 
          engine_model.append(em_reg)
    if len(engine_model) != 0:
      return list(chain(*engine_model))
    else: 
      return 0

def normalize_zero (row,unit_price):
    if row['Quantity'] == 0:
      if row['Cargo Value USD'] % unit_price < 2:
        return 1
      else:
        return row['Cargo Value USD'] // unit_price
    else:
        return row['Quantity']
    

def check_count_em (row,unit_price):
    if (row['count_em'] == 1) and (row['len_em'] > 1):
       if (row['Cargo Value USD'] < unit_price) or (row['Cargo Value USD'] == unit_price):
         return  round(row['Cargo Value USD']/row['len_em'],2)
       else:
         return unit_price

    elif (row['count_em'] > 1) and (row['len_em'] > 1):
        if (row['Cargo Value USD'] < row['count_em'] * unit_price) or (row['Cargo Value USD'] == row['count_em'] * unit_price):
           return  round(row['Cargo Value USD']/row['Quantity'],2)
#         elif row['Cargo Value USD'] > row['count_em'] * 266.77
#              return  round(row['Cargo Value USD']/row['len_em'],2)
        else:
            return row['count_em'] * unit_price
#             return  round(row['Cargo Value USD']/row['Quantity']*row['count_em'],2)
    elif ((row['count_em'] ==1) and (row['len_em'] == 1)):
       return  round(row['Cargo Value USD']/row['len_em'],2)
    else:
       return row['Cargo Value USD']



def count_length(list_em,em):
    count  = 0
    for i in list_em:
        if i == em:
            count+=1
    return count

# %%
# Load list all engine model in GTO
# df_merged = read_csv('list_all_em_GTO.csv',parse_dates=['Register Date'])
df_merged = read_csv('list_all_em_GTO.csv')
df_merged['Register Date'] = pd.to_datetime(df_merged['Register Date'],format='%Y-%m-%d')
df_merged.drop('Unnamed: 0',axis=1,inplace=True)
df_merged.head()
# Out:
#   Register Date     HS Code  \
# 0    2011-01-29  8407349908
# 1    2011-01-29  8407349908
# 2    2011-01-17  8407343009
# 3    2011-01-17  8407343009
# 4    2011-01-20  8407343009
#
#                                  Product Description  \
# 0  СИЛОВОЙ АГРЕГАТ TOYOTA 2TR-FE-261 В РАЗОБРАННО...
# 1  СИЛОВОЙ АГРЕГАТ TOYOTA 2TR-FE-A343E-111 В РАЗО...
# 2  ДВИГАТЕЛЬ ЗИЛ ,Б/У,БЕНЗИНОВЫЙ,ОБЪЕМ 6000СМ.КУБ...
# 3  ДВИГАТЕЛЬ ЗИЛ ,Б/У,НЕКОМПЛЕКТНЫЙ,БЕНЗИНОВЫЙ,ОБ...
# 4  ДВИГАТЕЛИ БЕНЗИНОВЫЕ В СБОРЕ С КОРОБКОЙ ПЕРЕДА...
#
#                     Producer            Brand Place of Receipt  \
# 0  TOYOTA TSUSHO CORPORATION      ОТСУТСТВУЕТ            КОТКА
# 1  TOYOTA TSUSHO CORPORATION      ОТСУТСТВУЕТ            КОТКА
# 2                   АМО ЗИЛ              ЗИЛ      ЕКАТЕРИНБУРГ
# 3                   АМО ЗИЛ              ЗИЛ      ЕКАТЕРИНБУРГ
# 4            MERCEDES - BENZ  MERCEDES - BENZ   ТОЯМА НЬЮ ПОРТ
#
#   Country of Origin  Country of Sales                      Shipper   \
# 0    JP, JPN, Japan    JP, JPN, Japan     TOYOTA TSUSHO CORPORATION
# 1    JP, JPN, Japan    JP, JPN, Japan     TOYOTA TSUSHO CORPORATION
# 2   RU, RUS, Russia  UA, UKR, Ukraine                   ООО ПЕТРУС
# 3   RU, RUS, Russia  UA, UKR, Ukraine                   ООО ПЕТРУС
# 4    JP, JPN, Japan    JP, JPN, Japan  METAL AUTO HOKURIKU CO., LTD
#
#                                   Shipper Address  \
# 0  450-8575 NAKAMURA-KU NAGOYA 9-8,MEIEKI 4-CHOME
# 1  450-8575 NAKAMURA-KU NAGOYA 9-8,MEIEKI 4-CHOME
# 2                  Г.ДРОГОБЫЧ УЛ.ГАЙДАМАЦКАЯ, 7/1
# 3                  Г.ДРОГОБЫЧ УЛ.ГАЙДАМАЦКАЯ, 7/1
# 4    ISHIKAWA KEN KOMATSU SHI SHIRAE MACHI, RO 62
#
#                          Consignee  \
# 0             ООО ТЕХНОСЕРВИСПРОМ
# 1             ООО ТЕХНОСЕРВИСПРОМ
# 2   ЗАО АВТОМОБИЛИ И МОТОРЫ УРАЛА
# 3   ЗАО АВТОМОБИЛИ И МОТОРЫ УРАЛА
# 4  ИП КОЧЕТКОВ ВЯЧЕСЛАВ ВИКТОРОВИЧ
#
#                                    Consignee Address  Quantity  \
# 0  603104, НИЖЕГОРОДСКАЯ ОБЛ, Н.НОВГОРОД, НАРТОВА...        15
# 1  603104, НИЖЕГОРОДСКАЯ ОБЛ, Н.НОВГОРОД, НАРТОВА...         5
# 2  624130, СВЕРДЛОВСКАЯ ОБЛ., Г.НОВОУРАЛЬСК, УЛ.А...        30
# 3  624130, СВЕРДЛОВСКАЯ ОБЛ., Г.НОВОУРАЛЬСК, УЛ.А...        15
# 4         664019, , Г ИРКУТСК, ПЕР. МИНУСИНСКИЙ Д 10        38
#
#   Unit of Measure Incoterms  Gross Weight in KG  Net Weight in KG  \
# 0              ШТ       CIF              3604.0            3017.0
# 1              ШТ       CIF              1765.0            1465.0
# 2              ШТ       CPT             14400.0           14400.0
# 3              ШТ       CPT              3000.0            3000.0
# 4              ШТ       FOB              6460.0            6460.0
#
#    Cargo Value USD
# 0         73063.36
# 1         37014.64
# 2         27000.00
# 3          6894.50
# 4          6536.45

# %%
for col in list(df_merged.columns):
 (df_merged[col].dtype ==  'object') and (df_merged[col].fillna(value='unknown',inplace = True)) or (df_merged[col].fillna(value=0, inplace = True))

# %%
# Load list engine model
df_list_engine = pd.read_excel('Engine Model _1025.xlsx')
df_list_engine.head()
# Out:
#    Unnamed: 0    メーカー   燃料 買付受付   型式 駆動1 駆動2  駆動3   詳細 車輌型式 KRA売単価   車名  仕入値  \
# 0         2.0    FIAT    0    ×    4  FR  AT  2WD  NaN  NaN    NaN  NaN  NaN
# 1         3.0  PORCHE  NaN    ×   64  RR  AT  4WD  NaN  NaN    NaN  NaN  NaN
# 2         4.0  PORCHE  NaN    ×   66  RR  MT  2WD  NaN  NaN    NaN  NaN  NaN
# 3         5.0  PORCHE  NaN    ×   70  RR  AT  4WD  NaN  NaN    NaN  NaN  NaN
# 4         6.0    BENZ  NaN    ○  102  FR  AT  2WD  NaN  NaN    NaN  NaN  NaN
#
#   EG売価\n（マニ触付）\nW EG売価\n（マニ触抜/無）\nWO
# 0            売価確認               売価確認
# 1            売価確認                  0
# 2            売価確認                  0
# 3            売価確認                  0
# 4           40000                  0

# %%
# Load list engine TOYOTA
df_brand_toyota =  df_list_engine[df_list_engine['メーカー']  == 'TOYOTA']
list_toyota = list(df_brand_toyota['型式'].unique())
list_toyota  = list(map(lambda x: x.split('-')[0],list_toyota))
list_toyota  = list(set(list_toyota))

# %%
df_brand_mazda =  df_list_engine[df_list_engine['メーカー']  == 'MAZDA']
list_mazda = list(df_brand_mazda['型式'].unique())
list_mazda  = list(map(lambda x: x.split('-')[0],list_mazda))
list_mazda  = list(set(list_mazda))

# %%
df_brand_mitsubishi =  df_list_engine[df_list_engine['メーカー']  == 'MITSUBISHI']
list_mitsubishi = list(df_brand_mitsubishi['型式'].unique())
list_mitsubishi  = list(map(lambda x: x.split('-')[0],list_mitsubishi))
list_mitsubishi  = list(set(list_mitsubishi))

# %%
df_brand_honda =  df_list_engine[df_list_engine['メーカー']  == 'HONDA']
list_honda = list(df_brand_honda['型式'].unique())
list_honda  = list(map(lambda x: x.split('-')[0],list_honda))
list_honda  = list(set(list_honda))

# %%
df_brand_nissan =  df_list_engine[df_list_engine['メーカー']  == 'NISSAN']
list_nissan = list(df_brand_nissan['型式'].unique())
list_nissan  = list(map(lambda x: x.split('-')[0],list_nissan))
list_nissan  = list(set(list_nissan))

# %%
df_brand_subaru =  df_list_engine[df_list_engine['メーカー']  == 'SUBARU']
list_subaru = list(df_brand_subaru['型式'].unique())
list_subaru  = list(map(lambda x: x.split('-')[0],list_subaru))
list_subaru  = list(set(list_subaru))

# %% [markdown]
# # Extract list engine of each brand

# %%
df_toyota_GTO = df_merged[df_merged.Producer.str.contains('TOYOTA')]
df_toyota_GTO['extracted_engine']  = df_toyota_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_toyota))
df_toyota_GTO['brand'] = 'TOYOTA'
df_toyota_GTO_extracted_em = df_toyota_GTO[df_toyota_GTO['extracted_engine'] !=0]
# Out:
# <ipython-input-13-2c10ef0cfc14>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_toyota_GTO['extracted_engine']  = df_toyota_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_toyota))
# <ipython-input-13-2c10ef0cfc14>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_toyota_GTO['brand'] = 'TOYOTA'

# %%
df_mazda_GTO = df_merged[df_merged.Producer.str.contains('MAZDA')]
df_mazda_GTO['brand'] = 'MAZDA'
df_mazda_GTO['extracted_engine']  = df_mazda_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_mazda))
df_mazda_GTO_extracted_em = df_mazda_GTO[df_mazda_GTO['extracted_engine'] !=0]
# Out:
# <ipython-input-14-55b0c9e7ffc8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mazda_GTO['brand'] = 'MAZDA'
# <ipython-input-14-55b0c9e7ffc8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mazda_GTO['extracted_engine']  = df_mazda_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_mazda))

# %%
df_mitsubishi_GTO = df_merged[df_merged.Producer.str.contains('MITSUBISHI')]
df_mitsubishi_GTO['brand'] = 'MITSUBISHI'
df_mitsubishi_GTO['extracted_engine']  = df_mitsubishi_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_mitsubishi))
df_mitsubishi_GTO_extracted_em = df_mitsubishi_GTO[df_mitsubishi_GTO['extracted_engine'] !=0]
# Out:
# <ipython-input-15-a3695c5d34da>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mitsubishi_GTO['brand'] = 'MITSUBISHI'
# <ipython-input-15-a3695c5d34da>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mitsubishi_GTO['extracted_engine']  = df_mitsubishi_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_mitsubishi))

# %%
df_mitsubishi_GTO_extracted_em
# Out:
#        Register Date     HS Code  \
# 12        2011-01-18  8407343009
# 22        2011-01-27  8407343009
# 45        2011-01-13  8407343009
# 55        2011-01-14  8407343009
# 91        2011-01-21  8407343009
# ...              ...         ...
# 258988    2019-12-01  8407343009
# 259055    2019-12-01  8407343009
# 259068    2019-12-01  8407343009
# 259138    2019-12-01  8407343009
# 259177    2019-12-01  8407343009
#
#                                       Product Description  \
# 12      ДВС ОТ А/М, Б/У, В СБОРЕ С КПП, БЕНЗИН: HONDA,...
# 22      ДВС ОТ А/М, Б/У, В СБОРЕ С КПП, БЕНЗИН: HONDA,...
# 45      ДВИГАТЕЛЬ БЕНЗИН.ДЛЯ ЛЕГ.А/М,Б/У,ЯП.ПР-ВА В СБ...
# 55      ДВИГАТЕЛЬ БЕНЗИНОВЫЙ, БЫВШИЙ В УПОТРЕБЛЕНИИ, Д...
# 91      ЗАП.ЧАСТИ ДЛЯ А/М, Б/У ДВИГАТЕЛЯ С АКП ЯПОНСКО...
# ...                                                   ...
# 258988  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ ДЛЯ А/М БЫВШИЙ В УПОТРЕБЛ...
# 259055  ДВИГАТЕЛЬ ОТ А/М Б/У С АКП ,БЕНЗИНОВЫЙ ОБЪЕМОМ...
# 259068  ДВИГАТЕЛИ-2ШТ.БЫВШ.В УПОТР.КАРБЮРАТ.ОБЪЕМ 1834...
# 259138  ДВИГАТЕЛИ ВНУТРЕННЕГО СГОРАНИЯ БЫВШИЕ В УПОТРЕ...
# 259177  ДВИГАТЕЛЬ ОТ А/М Б/У С АКП ,БЕНЗИНОВЫЙ ОБЪЕМОМ...
#
#                                                  Producer  \
# 12      HONDA, MAZDA, MITSUBISHI, NISSAN, SUBARU, SUZU...
# 22       HONDA, MAZDA, MITSUBISHI, NISSAN, SUBARU, TOYOTA
# 45      NISSAN, MITSUBISHI,TOYOTA,MAZDA,HONDA,SUBARU,D...
# 55               TOYOTA, HONDA, MAZDA, NISSAN, MITSUBISHI
# 91                               TOYOTA,MITSUBISHI,SUBARU
# ...                                                   ...
# 258988                           MITSUBISHI SUBARU SUZUKI
# 259055                                         MITSUBISHI
# 259068                               MITSUBISHI MOTOR CO.
# 259138  FUJI HEAVY INDUSTRIES CO.LTDMITSUBISHI MOTORS ...
# 259177                                         MITSUBISHI
#
#                                                     Brand Place of Receipt  \
# 12      HONDA, MAZDA, MITSUBISHI, NISSAN, SUBARU, SUZU...             КОБЕ
# 22       HONDA, MAZDA, MITSUBISHI, NISSAN, SUBARU, TOYOTA             КОБЕ
# 45      NISSAN, MITSUBISHI, TOYOTA,MAZDA,SUBARU,HONDA,...      ВЛАДИВОСТОК
# 55               TOYOTA, HONDA, MAZDA, NISSAN, MITSUBISHI      ВЛАДИВОСТОК
# 91                               TOYOTA,MITSUBISHI,SUBARU      ВЛАДИВОСТОК
# ...                                                   ...              ...
# 258988                           MITSUBISHI SUBARU SUZUKI     TOYAMASHINKO
# 259055                                         MITSUBISHI      ВЛАДИВОСТОК
# 259068                                         MITSUBISHI        ВОСТОЧНЫЙ
# 259138                                   SUBARUMITSUBISHI        ВОСТОЧНЫЙ
# 259177                                         MITSUBISHI      ВЛАДИВОСТОК
#
#        Country of Origin Country of Sales  \
# 12        JP, JPN, Japan   JP, JPN, Japan
# 22        JP, JPN, Japan   JP, JPN, Japan
# 45        JP, JPN, Japan   JP, JPN, Japan
# 55        JP, JPN, Japan   JP, JPN, Japan
# 91        JP, JPN, Japan   JP, JPN, Japan
# ...                  ...              ...
# 258988    JP, JPN, Japan   JP, JPN, Japan
# 259055    JP, JPN, Japan   JP, JPN, Japan
# 259068    JP, JPN, Japan   JP, JPN, Japan
# 259138    JP, JPN, Japan   JP, JPN, Japan
# 259177    JP, JPN, Japan   JP, JPN, Japan
#
#                                                  Shipper   \
# 12                                       J-TRADE CO., LTD
# 22                                       J-TRADE CO., LTD
# 45                                       LEEA CORPORATION
# 55                                  HIKARI SYOJI CO.,LTD
# 91                                 АВТОЛОМ ДЖАПАН КО.,ЛТД
# ...                                                   ...
# 258988  FESCO INTEGRATED TRANSPORY LLC O/B OF KAIHO IN...
# 259055                                       UNICO CO LTD
# 259068                                    SUNTEC CO. LTD.
# 259138              WEST-JAPAN AUTO RECYCLE CO.LTD (WARC)
# 259177                                       UNICO CO LTD
#
#                                           Shipper Address  \
# 12            614-8051 КЙОТО ЯВАТА-СИТИ ЯВАТА-ЯМАДА, 67-3
# 22            614-8051 КЙОТО ЯВАТА-СИТИ ЯВАТА-ЯМАДА, 67-3
# 45                       HIROSHIMA TAKAYADAI 2-CHOME, 1-8
# 55                     KYOTO YAWATA-CITY 27, YAWATAKUBOTA
# 91      17-1 ДЖАПАН ПУСАН НИШИДЕГУЧИ,АЗА 16 ХАСУГАУРА,...
# ...                                                   ...
# 258988  920-0209, ISHIKAWA KEN, KANAZAWA-SHI, 1-25 HIG...
# 259055               ЯПОНИЯ, ЙОКОГАМА, АСОНА, БИЗИН 926-3
# 259068            KIYOSE-CITY, TOKYO, 6-95-1-105 NAKAZATO
# 259138  1-62, FUKUOKA, KITAKYUSHU, HIBIKIMACHI, WAKAMA...
# 259177               ЯПОНИЯ, ЙОКОГАМА, АСОНА, БИЗИН 926-3
#
#                                                 Consignee  \
# 12                        ИП КАРПЕНОК НАТАЛЬЯ ГЕННАДЬЕВНА
# 22      КАРПЕНОК НАТАЛЬЯ ГЕНАДЬЕВНА ПАСПОРТ 0503№28165...
# 45                                          ООО РДС-АВТО
# 55                             САКУРА МОТОРС КЕМЕРОВО ООО
# 91                                         ООО ДВ-МОТОРС
# ...                                                   ...
# 258988                                      ООО АВТОСТОК
# 259055                    ИП МАТВЕЕВ СТАНИСЛАВ ВАЛЕРЬЕВИЧ
# 259068                      ИП ФОМИЧЕВ АЛЕКСАНДР ИВАНОВИЧ
# 259138                                         ООО ПАРУС
# 259177                    ИП МАТВЕЕВ СТАНИСЛАВ ВАЛЕРЬЕВИЧ
#
#                                         Consignee Address  Quantity  \
# 12      690105, ПРИМОРСКИЙ КРАЙ, Г. ВЛАДИВОСТОК, УЛ. Р...        22
# 22      690105, ПРИМОРСКИЙ КРАЙ, ВЛАДИВОСТОК, РУССКАЯ ...        19
# 45      690066, ПРИМОРСКИЙ КРАЙ, ВЛАДИВОСТОК, УЛ.ШИЛКИ...        35
# 55      650010, КЕМЕРОВСКАЯ ОБЛАСТЬ, КЕМЕРОВО, МАЯКОВС...        34
# 91      690065, ПРИМОРСКИЙ КРАЙ, Г. ВЛАДИВОСТОК, УЛ. С...         3
# ...                                                   ...       ...
# 258988  630088, ГОРОД НОВОСИБИРСК, СЕВЕРНЫЙ ПРОЕЗД, Д ...         0
# 259055                          630000, ГОРОД НОВОСИБИРСК         0
# 259068                          630000, ГОРОД НОВОСИБИРСК         0
# 259138  650040, 650040, ОБЛАСТЬ КЕМЕРОВСКАЯ ОБЛАСТЬ - ...         0
# 259177                          630000, ГОРОД НОВОСИБИРСК         0
#
#        Unit of Measure Incoterms  Gross Weight in KG  Net Weight in KG  \
# 12                  ШТ       FOB              5500.0            5500.0
# 22                  ШТ       FOB              4750.0            4750.0
# 45                  ШТ       CFR             10255.0           10255.0
# 55                  ШТ       CFR              7235.0            7235.0
# 91                  ШТ       CFR               600.0             600.0
# ...                ...       ...                 ...               ...
# 258988         unknown       FOB              2125.0            2070.0
# 259055         unknown       CFR               467.0             467.0
# 259068         unknown       CFR               460.0             460.0
# 259138         unknown       CFR               760.0             760.0
# 259177         unknown       CFR               467.0             467.0
#
#         Cargo Value USD       brand extracted_engine
# 12              3339.77  MITSUBISHI           [4G93]
# 22              2867.72  MITSUBISHI     [6G73, 6G73]
# 45              6160.00  MITSUBISHI           [4G93]
# 55              3945.00  MITSUBISHI           [4G93]
# 91               480.00  MITSUBISHI           [4G15]
# ...                 ...         ...              ...
# 258988          3133.66  MITSUBISHI     [4G94, 4G93]
# 259055           706.00  MITSUBISHI           [4G93]
# 259068           720.70  MITSUBISHI     [4G63, 4G93]
# 259138          1148.61  MITSUBISHI           [6G73]
# 259177           706.00  MITSUBISHI           [4G93]
#
# [6157 rows x 20 columns]

# %%
df_honda_GTO = df_merged[df_merged.Producer.str.contains('HONDA')]
df_honda_GTO['brand'] = 'HONDA'
df_honda_GTO['extracted_engine']  = df_honda_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_honda))
df_honda_GTO_extracted_em = df_honda_GTO[df_honda_GTO['extracted_engine'] !=0]
# Out:
# <ipython-input-17-0c8c0f52b4a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_honda_GTO['brand'] = 'HONDA'
# <ipython-input-17-0c8c0f52b4a5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_honda_GTO['extracted_engine']  = df_honda_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_honda))

# %%
df_nissan_GTO = df_merged[df_merged.Producer.str.contains('NISSAN')]
df_nissan_GTO['brand'] = 'NISSAN'
df_nissan_GTO['extracted_engine']  = df_nissan_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_nissan))
df_nissan_GTO_extracted_em = df_nissan_GTO[df_nissan_GTO['extracted_engine'] !=0]
# Out:
# <ipython-input-18-edd9724bdd48>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nissan_GTO['brand'] = 'NISSAN'
# <ipython-input-18-edd9724bdd48>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nissan_GTO['extracted_engine']  = df_nissan_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_nissan))

# %%
df_subaru_GTO = df_merged[df_merged.Producer.str.contains('SUBARU')]
df_subaru_GTO['brand'] = 'SUBARU'
df_subaru_GTO['extracted_engine']  = df_subaru_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_subaru))
df_subaru_GTO_extracted_em = df_subaru_GTO[df_subaru_GTO['extracted_engine'] != 0]
# Out:
# <ipython-input-19-72adf53e9231>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subaru_GTO['brand'] = 'SUBARU'
# <ipython-input-19-72adf53e9231>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subaru_GTO['extracted_engine']  = df_subaru_GTO['Product Description'].map(lambda x : extract_engine_data (x, list_subaru))

# %%
list_brand  = [df_toyota_GTO_extracted_em,df_mazda_GTO_extracted_em,df_mitsubishi_GTO_extracted_em,df_honda_GTO_extracted_em,df_nissan_GTO_extracted_em,df_subaru_GTO_extracted_em]
df_all = pd.concat(list_brand)

# %%
df_all['extracted_engine'] = df_all.extracted_engine.map(tuple)
df_all.drop_duplicates()
# Out:
#        Register Date     HS Code  \
# 0         2011-01-29  8407349908
# 1         2011-01-29  8407349908
# 6         2011-01-06  8407343009
# 10        2011-01-13  8407343009
# 11        2011-01-17  8407343009
# ...              ...         ...
# 258909    2019-12-01  8407343009
# 258910    2019-12-01  8407343009
# 258942    2019-12-01  8407343009
# 258988    2019-12-01  8407343009
# 259059    2019-12-01  8407343009
#
#                                       Product Description  \
# 0       СИЛОВОЙ АГРЕГАТ TOYOTA 2TR-FE-261 В РАЗОБРАННО...
# 1       СИЛОВОЙ АГРЕГАТ TOYOTA 2TR-FE-A343E-111 В РАЗО...
# 6       ДВС БЕНЗИН А/М Б/У В СБОРЕ С АКП: TOYOTA,1JZ-0...
# 10      ДВС БЕНЗИН А/М Б/У В СБОРЕ С АКП: TOYOTA,5K-12...
# 11      ДВС БЕНЗИН А/М Б/У В СБОРЕ С АКП: TOYOTA,5K-12...
# ...                                                   ...
# 258909  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 258910  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 258942  ДВИГАТЕЛИ БЕНЗИНОВЫЕ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 258988  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ ДЛЯ А/М БЫВШИЙ В УПОТРЕБЛ...
# 259059  ДВИГАТЕЛЬ ОТ А/М Б/У С АКП ,БЕНЗИНОВЫЙ ОБЪЕМОМ...
#
#                          Producer                     Brand Place of Receipt  \
# 0       TOYOTA TSUSHO CORPORATION               ОТСУТСТВУЕТ            КОТКА
# 1       TOYOTA TSUSHO CORPORATION               ОТСУТСТВУЕТ            КОТКА
# 6                          TOYOTA                    TOYOTA      ВЛАДИВОСТОК
# 10                         TOYOTA                    TOYOTA      ВЛАДИВОСТОК
# 11                         TOYOTA                    TOYOTA      ВЛАДИВОСТОК
# ...                           ...                       ...              ...
# 258909                     SUBARU                    SUBARU      ВЛАДИВОСТОК
# 258910                     SUBARU                    SUBARU      ВЛАДИВОСТОК
# 258942         SUBARU CORPORATION                    SUBARU      ВЛАДИВОСТОК
# 258988   MITSUBISHI SUBARU SUZUKI  MITSUBISHI SUBARU SUZUKI     TOYAMASHINKO
# 259059            SUBARU DAIHATSU           SUBARU DAIHATSU      ВЛАДИВОСТОК
#
#        Country of Origin Country of Sales  \
# 0         JP, JPN, Japan   JP, JPN, Japan
# 1         JP, JPN, Japan   JP, JPN, Japan
# 6         JP, JPN, Japan   JP, JPN, Japan
# 10        JP, JPN, Japan   JP, JPN, Japan
# 11        JP, JPN, Japan   JP, JPN, Japan
# ...                  ...              ...
# 258909    JP, JPN, Japan   JP, JPN, Japan
# 258910    JP, JPN, Japan   JP, JPN, Japan
# 258942    JP, JPN, Japan   JP, JPN, Japan
# 258988    JP, JPN, Japan   JP, JPN, Japan
# 259059    JP, JPN, Japan   JP, JPN, Japan
#
#                                                  Shipper   \
# 0                               TOYOTA TSUSHO CORPORATION
# 1                               TOYOTA TSUSHO CORPORATION
# 6                                  МИХАИЛ КАМПАНИ КО.,ЛТД
# 10                                 МИХАИЛ КАМПАНИ КО.,ЛТД
# 11                                 МИХАИЛ КАМПАНИ КО.,ЛТД
# ...                                                   ...
# 258909                                    D-JAPAN CO. LTD
# 258910                                    D-JAPAN CO. LTD
# 258942                                          AL EXPORT
# 258988  FESCO INTEGRATED TRANSPORY LLC O/B OF KAIHO IN...
# 259059                                       UNICO CO LTD
#
#                                           Shipper Address  \
# 0          450-8575 NAKAMURA-KU NAGOYA 9-8,MEIEKI 4-CHOME
# 1          450-8575 NAKAMURA-KU NAGOYA 9-8,MEIEKI 4-CHOME
# 6          910-0049 ФУКУИ-КЕН ФУКУИ-ШИ ФУКАДАНИ-ЧО, 1-7-3
# 10         910-0049 ФУКУИ-КЕН ФУКУИ-ШИ ФУКАДАНИ-ЧО, 1-7-3
# 11         910-0049 ФУКУИ-КЕН ФУКУИ-ШИ ФУКАДАНИ-ЧО, 1-7-3
# ...                                                   ...
# 258909  HOKKAIDO, HIGASHITAKASU ASAHIKAWA, 2149-13, HI...
# 258910  HOKKAIDO, HIGASHITAKASU ASAHIKAWA, 2149-13, HI...
# 258942       875-1, KAMONOFU, SINGU, FUKUOKA PREF, KASUYA
# 258988  920-0209, ISHIKAWA KEN, KANAZAWA-SHI, 1-25 HIG...
# 259059               ЯПОНИЯ, ЙОКОГАМА, АСОНА, БИЗИН 926-3
#
#                               Consignee  \
# 0                  ООО ТЕХНОСЕРВИСПРОМ
# 1                  ООО ТЕХНОСЕРВИСПРОМ
# 6                          НИКА ВЭД ООО
# 10                         НИКА ВЭД ООО
# 11                         НИКА ВЭД ООО
# ...                                 ...
# 258909                         ООО ВКС
# 258910                         ООО ВКС
# 258942                   ООО КАСТОМ-ВЛ
# 258988                    ООО АВТОСТОК
# 259059  ИП МАТВЕЕВ СТАНИСЛАВ ВАЛЕРЬЕВИЧ
#
#                                         Consignee Address  Quantity  \
# 0       603104, НИЖЕГОРОДСКАЯ ОБЛ, Н.НОВГОРОД, НАРТОВА...        15
# 1       603104, НИЖЕГОРОДСКАЯ ОБЛ, Н.НОВГОРОД, НАРТОВА...         5
# 6       690002, ПРИМОРСКИЙ КРАЙ, Г.ВЛАДИВОСТОК, НЕКРАС...         1
# 10      690002, ПРИМОРСКИЙ КРАЙ, Г.ВЛАДИВОСТОК, НЕКРАС...         3
# 11      690002, ПРИМОРСКИЙ КРАЙ, Г.ВЛАДИВОСТОК, НЕКРАС...         3
# ...                                                   ...       ...
# 258909  690002, ГОРОД ВЛАДИВОСТОК, ПР-КТ КРАСНОГО ЗНАМ...         0
# 258910  690002, ГОРОД ВЛАДИВОСТОК, ПР-КТ КРАСНОГО ЗНАМ...         0
# 258942  690003, ГОРОД ВЛАДИВОСТОК, УЛ НИЖНЕПОРТОВАЯ, Д...         0
# 258988  630088, ГОРОД НОВОСИБИРСК, СЕВЕРНЫЙ ПРОЕЗД, Д ...         0
# 259059                          630000, ГОРОД НОВОСИБИРСК         0
#
#        Unit of Measure Incoterms  Gross Weight in KG  Net Weight in KG  \
# 0                   ШТ       CIF              3604.0            3017.0
# 1                   ШТ       CIF              1765.0            1465.0
# 6                   ШТ       CFR               150.0             150.0
# 10                  ШТ       CFR               450.0             450.0
# 11                  ШТ       CFR               450.0             450.0
# ...                ...       ...                 ...               ...
# 258909         unknown       CFR               200.0             200.0
# 258910         unknown       CFR               200.0             200.0
# 258942         unknown       CFR               220.0             220.0
# 258988         unknown       FOB              2125.0            2070.0
# 259059         unknown       CFR               383.0             383.0
#
#         Cargo Value USD extracted_engine   brand
# 0              73063.36       (2TR, 2TR)  TOYOTA
# 1              37014.64       (2TR, 2TR)  TOYOTA
# 6                120.00           (1JZ,)  TOYOTA
# 10               360.00   (2TR, 2UZ, 5K)  TOYOTA
# 11               360.00   (2TR, 2UZ, 5K)  TOYOTA
# ...                 ...              ...     ...
# 258909           302.00          (EJ20,)  SUBARU
# 258910           302.00          (EJ20,)  SUBARU
# 258942           332.20          (EJ20,)  SUBARU
# 258988          3133.66          (EJ15,)  SUBARU
# 259059           578.00          (FB20,)  SUBARU
#
# [43750 rows x 20 columns]

# %%
df_all['extracted_engine'] = df_all.extracted_engine.map(list)

# %%
df_copy = df_all.copy().reset_index()
df_copy['month_year'] = df_copy['Register Date'].dt.strftime('%Y-%m')
df_copy['year'] =  df_copy['Register Date'].dt.strftime('%Y')
df_copy['len_unique_em'] = df_copy['extracted_engine'].map(lambda x : len(set(x)))
df_copy['len_em'] = df_copy['extracted_engine'].map(lambda x : len(x))
df_copy
# Out:
#         index Register Date     HS Code  \
# 0           0    2011-01-29  8407349908
# 1           1    2011-01-29  8407349908
# 2           6    2011-01-06  8407343009
# 3          10    2011-01-13  8407343009
# 4          11    2011-01-17  8407343009
# ...       ...           ...         ...
# 43878  258910    2019-12-01  8407343009
# 43879  258942    2019-12-01  8407343009
# 43880  258988    2019-12-01  8407343009
# 43881  259059    2019-12-01  8407343009
# 43882  259159    2019-12-01  8407343009
#
#                                      Product Description  \
# 0      СИЛОВОЙ АГРЕГАТ TOYOTA 2TR-FE-261 В РАЗОБРАННО...
# 1      СИЛОВОЙ АГРЕГАТ TOYOTA 2TR-FE-A343E-111 В РАЗО...
# 2      ДВС БЕНЗИН А/М Б/У В СБОРЕ С АКП: TOYOTA,1JZ-0...
# 3      ДВС БЕНЗИН А/М Б/У В СБОРЕ С АКП: TOYOTA,5K-12...
# 4      ДВС БЕНЗИН А/М Б/У В СБОРЕ С АКП: TOYOTA,5K-12...
# ...                                                  ...
# 43878  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43879  ДВИГАТЕЛИ БЕНЗИНОВЫЕ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43880  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ ДЛЯ А/М БЫВШИЙ В УПОТРЕБЛ...
# 43881  ДВИГАТЕЛЬ ОТ А/М Б/У С АКП ,БЕНЗИНОВЫЙ ОБЪЕМОМ...
# 43882  ДВИГАТЕЛЬ ОТ А/М Б/У С АКП ,БЕНЗИНОВЫЙ ОБЪЕМОМ...
#
#                         Producer                     Brand Place of Receipt  \
# 0      TOYOTA TSUSHO CORPORATION               ОТСУТСТВУЕТ            КОТКА
# 1      TOYOTA TSUSHO CORPORATION               ОТСУТСТВУЕТ            КОТКА
# 2                         TOYOTA                    TOYOTA      ВЛАДИВОСТОК
# 3                         TOYOTA                    TOYOTA      ВЛАДИВОСТОК
# 4                         TOYOTA                    TOYOTA      ВЛАДИВОСТОК
# ...                          ...                       ...              ...
# 43878                     SUBARU                    SUBARU      ВЛАДИВОСТОК
# 43879         SUBARU CORPORATION                    SUBARU      ВЛАДИВОСТОК
# 43880   MITSUBISHI SUBARU SUZUKI  MITSUBISHI SUBARU SUZUKI     TOYAMASHINKO
# 43881            SUBARU DAIHATSU           SUBARU DAIHATSU      ВЛАДИВОСТОК
# 43882            SUBARU DAIHATSU           SUBARU DAIHATSU      ВЛАДИВОСТОК
#
#       Country of Origin Country of Sales  \
# 0        JP, JPN, Japan   JP, JPN, Japan
# 1        JP, JPN, Japan   JP, JPN, Japan
# 2        JP, JPN, Japan   JP, JPN, Japan
# 3        JP, JPN, Japan   JP, JPN, Japan
# 4        JP, JPN, Japan   JP, JPN, Japan
# ...                 ...              ...
# 43878    JP, JPN, Japan   JP, JPN, Japan
# 43879    JP, JPN, Japan   JP, JPN, Japan
# 43880    JP, JPN, Japan   JP, JPN, Japan
# 43881    JP, JPN, Japan   JP, JPN, Japan
# 43882    JP, JPN, Japan   JP, JPN, Japan
#
#                                                 Shipper   ... Incoterms  \
# 0                              TOYOTA TSUSHO CORPORATION  ...       CIF
# 1                              TOYOTA TSUSHO CORPORATION  ...       CIF
# 2                                 МИХАИЛ КАМПАНИ КО.,ЛТД  ...       CFR
# 3                                 МИХАИЛ КАМПАНИ КО.,ЛТД  ...       CFR
# 4                                 МИХАИЛ КАМПАНИ КО.,ЛТД  ...       CFR
# ...                                                  ...  ...       ...
# 43878                                    D-JAPAN CO. LTD  ...       CFR
# 43879                                          AL EXPORT  ...       CFR
# 43880  FESCO INTEGRATED TRANSPORY LLC O/B OF KAIHO IN...  ...       FOB
# 43881                                       UNICO CO LTD  ...       CFR
# 43882                                       UNICO CO LTD  ...       CFR
#
#       Gross Weight in KG Net Weight in KG  Cargo Value USD extracted_engine  \
# 0                 3604.0           3017.0         73063.36       [2TR, 2TR]
# 1                 1765.0           1465.0         37014.64       [2TR, 2TR]
# 2                  150.0            150.0           120.00            [1JZ]
# 3                  450.0            450.0           360.00   [2TR, 2UZ, 5K]
# 4                  450.0            450.0           360.00   [2TR, 2UZ, 5K]
# ...                  ...              ...              ...              ...
# 43878              200.0            200.0           302.00           [EJ20]
# 43879              220.0            220.0           332.20           [EJ20]
# 43880             2125.0           2070.0          3133.66           [EJ15]
# 43881              383.0            383.0           578.00           [FB20]
# 43882              383.0            383.0           578.00           [FB20]
#
#         brand  month_year  year  len_unique_em len_em
# 0      TOYOTA     2011-01  2011              1      2
# 1      TOYOTA     2011-01  2011              1      2
# 2      TOYOTA     2011-01  2011              1      1
# 3      TOYOTA     2011-01  2011              3      3
# 4      TOYOTA     2011-01  2011              3      3
# ...       ...         ...   ...            ...    ...
# 43878  SUBARU     2019-12  2019              1      1
# 43879  SUBARU     2019-12  2019              1      1
# 43880  SUBARU     2019-12  2019              1      1
# 43881  SUBARU     2019-12  2019              1      1
# 43882  SUBARU     2019-12  2019              1      1
#
# [43883 rows x 25 columns]

# %%
df_copy[df_copy.brand == 'MITSUBISHI']
# Out:
#         index Register Date     HS Code  \
# 24123      12    2011-01-18  8407343009
# 24124      22    2011-01-27  8407343009
# 24125      45    2011-01-13  8407343009
# 24126      55    2011-01-14  8407343009
# 24127      91    2011-01-21  8407343009
# ...       ...           ...         ...
# 30275  258988    2019-12-01  8407343009
# 30276  259055    2019-12-01  8407343009
# 30277  259068    2019-12-01  8407343009
# 30278  259138    2019-12-01  8407343009
# 30279  259177    2019-12-01  8407343009
#
#                                      Product Description  \
# 24123  ДВС ОТ А/М, Б/У, В СБОРЕ С КПП, БЕНЗИН: HONDA,...
# 24124  ДВС ОТ А/М, Б/У, В СБОРЕ С КПП, БЕНЗИН: HONDA,...
# 24125  ДВИГАТЕЛЬ БЕНЗИН.ДЛЯ ЛЕГ.А/М,Б/У,ЯП.ПР-ВА В СБ...
# 24126  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ, БЫВШИЙ В УПОТРЕБЛЕНИИ, Д...
# 24127  ЗАП.ЧАСТИ ДЛЯ А/М, Б/У ДВИГАТЕЛЯ С АКП ЯПОНСКО...
# ...                                                  ...
# 30275  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ ДЛЯ А/М БЫВШИЙ В УПОТРЕБЛ...
# 30276  ДВИГАТЕЛЬ ОТ А/М Б/У С АКП ,БЕНЗИНОВЫЙ ОБЪЕМОМ...
# 30277  ДВИГАТЕЛИ-2ШТ.БЫВШ.В УПОТР.КАРБЮРАТ.ОБЪЕМ 1834...
# 30278  ДВИГАТЕЛИ ВНУТРЕННЕГО СГОРАНИЯ БЫВШИЕ В УПОТРЕ...
# 30279  ДВИГАТЕЛЬ ОТ А/М Б/У С АКП ,БЕНЗИНОВЫЙ ОБЪЕМОМ...
#
#                                                 Producer  \
# 24123  HONDA, MAZDA, MITSUBISHI, NISSAN, SUBARU, SUZU...
# 24124   HONDA, MAZDA, MITSUBISHI, NISSAN, SUBARU, TOYOTA
# 24125  NISSAN, MITSUBISHI,TOYOTA,MAZDA,HONDA,SUBARU,D...
# 24126           TOYOTA, HONDA, MAZDA, NISSAN, MITSUBISHI
# 24127                           TOYOTA,MITSUBISHI,SUBARU
# ...                                                  ...
# 30275                           MITSUBISHI SUBARU SUZUKI
# 30276                                         MITSUBISHI
# 30277                               MITSUBISHI MOTOR CO.
# 30278  FUJI HEAVY INDUSTRIES CO.LTDMITSUBISHI MOTORS ...
# 30279                                         MITSUBISHI
#
#                                                    Brand Place of Receipt  \
# 24123  HONDA, MAZDA, MITSUBISHI, NISSAN, SUBARU, SUZU...             КОБЕ
# 24124   HONDA, MAZDA, MITSUBISHI, NISSAN, SUBARU, TOYOTA             КОБЕ
# 24125  NISSAN, MITSUBISHI, TOYOTA,MAZDA,SUBARU,HONDA,...      ВЛАДИВОСТОК
# 24126           TOYOTA, HONDA, MAZDA, NISSAN, MITSUBISHI      ВЛАДИВОСТОК
# 24127                           TOYOTA,MITSUBISHI,SUBARU      ВЛАДИВОСТОК
# ...                                                  ...              ...
# 30275                           MITSUBISHI SUBARU SUZUKI     TOYAMASHINKO
# 30276                                         MITSUBISHI      ВЛАДИВОСТОК
# 30277                                         MITSUBISHI        ВОСТОЧНЫЙ
# 30278                                   SUBARUMITSUBISHI        ВОСТОЧНЫЙ
# 30279                                         MITSUBISHI      ВЛАДИВОСТОК
#
#       Country of Origin Country of Sales  \
# 24123    JP, JPN, Japan   JP, JPN, Japan
# 24124    JP, JPN, Japan   JP, JPN, Japan
# 24125    JP, JPN, Japan   JP, JPN, Japan
# 24126    JP, JPN, Japan   JP, JPN, Japan
# 24127    JP, JPN, Japan   JP, JPN, Japan
# ...                 ...              ...
# 30275    JP, JPN, Japan   JP, JPN, Japan
# 30276    JP, JPN, Japan   JP, JPN, Japan
# 30277    JP, JPN, Japan   JP, JPN, Japan
# 30278    JP, JPN, Japan   JP, JPN, Japan
# 30279    JP, JPN, Japan   JP, JPN, Japan
#
#                                                 Shipper   ... Incoterms  \
# 24123                                   J-TRADE CO., LTD  ...       FOB
# 24124                                   J-TRADE CO., LTD  ...       FOB
# 24125                                   LEEA CORPORATION  ...       CFR
# 24126                              HIKARI SYOJI CO.,LTD   ...       CFR
# 24127                             АВТОЛОМ ДЖАПАН КО.,ЛТД  ...       CFR
# ...                                                  ...  ...       ...
# 30275  FESCO INTEGRATED TRANSPORY LLC O/B OF KAIHO IN...  ...       FOB
# 30276                                       UNICO CO LTD  ...       CFR
# 30277                                    SUNTEC CO. LTD.  ...       CFR
# 30278              WEST-JAPAN AUTO RECYCLE CO.LTD (WARC)  ...       CFR
# 30279                                       UNICO CO LTD  ...       CFR
#
#       Gross Weight in KG Net Weight in KG  Cargo Value USD extracted_engine  \
# 24123             5500.0           5500.0          3339.77           [4G93]
# 24124             4750.0           4750.0          2867.72     [6G73, 6G73]
# 24125            10255.0          10255.0          6160.00           [4G93]
# 24126             7235.0           7235.0          3945.00           [4G93]
# 24127              600.0            600.0           480.00           [4G15]
# ...                  ...              ...              ...              ...
# 30275             2125.0           2070.0          3133.66     [4G94, 4G93]
# 30276              467.0            467.0           706.00           [4G93]
# 30277              460.0            460.0           720.70     [4G63, 4G93]
# 30278              760.0            760.0          1148.61           [6G73]
# 30279              467.0            467.0           706.00           [4G93]
#
#             brand  month_year  year  len_unique_em len_em
# 24123  MITSUBISHI     2011-01  2011              1      1
# 24124  MITSUBISHI     2011-01  2011              1      2
# 24125  MITSUBISHI     2011-01  2011              1      1
# 24126  MITSUBISHI     2011-01  2011              1      1
# 24127  MITSUBISHI     2011-01  2011              1      1
# ...           ...         ...   ...            ...    ...
# 30275  MITSUBISHI     2019-12  2019              2      2
# 30276  MITSUBISHI     2019-12  2019              1      1
# 30277  MITSUBISHI     2019-12  2019              2      2
# 30278  MITSUBISHI     2019-12  2019              1      1
# 30279  MITSUBISHI     2019-12  2019              1      1
#
# [6157 rows x 25 columns]

# %%
#       B20B	4431	16.59
# 21	F23A	2681	10.04
# 10	D15B	2577	9.65
# 33	L13A	2443	9.15
# 11	D16A	2025	7.58
# Out:
#   File "<ipython-input-27-1ec05c1b6381>", line 8
#     if (!Jupyter.toolbar.actions.get('cellfreezer:freeze')) {
#         ^
# SyntaxError: invalid syntax

# %%
# %%javascript
# if (!Jupyter.toolbar.actions.get('cellfreezer:freeze')) {
#     Jupyter.toolbar.actions.register({
#       icon: 'fa-thumb-tack',
#       handler: function() {
#         var cell = Jupyter.notebook.get_selected_cell().element[0];
#         if (!cell.style.position) {
#           cell.style.position = 'fixed';
#           cell.style.top = '0px';
#           cell.style.left = '0px';
#           cell.style['z-index'] = 999;
#           cell.style.background = 'rgba(234, 211, 146, 0.88)';
#           cell.style.width = '50%';
#         } else {
#           cell.style.position = '';
#           cell.style.top = '';
#           cell.style.left = '';
#           cell.style['z-index'] = '';
#           cell.style.background = '';
#           cell.style.width = '';
#         }
#       }
#     }, 'freeze', 'cellfreezer');
#     Jupyter.toolbar.add_buttons_group(['cellfreezer:freeze']);
#     Jupyter.keyboard_manager.command_shortcuts.add_shortcut('q', 'cellfreezer:freeze');
# }

# %% [markdown]
# # SUBARU: EM =  EJ20

# %%
# df_copy.extracted_engine.map(list)
df_3s  = df_copy[df_copy["extracted_engine"].apply(lambda x : 'EJ20' in x)]
df_3s
# Out:
#         index Register Date     HS Code  \
# 40137      20    2011-01-25  8407343009
# 40139      35    2011-01-12  8407343009
# 40140      91    2011-01-21  8407343009
# 40142    1011    2011-01-25  8407343009
# 40143    1483    2011-02-07  8407343009
# ...       ...           ...         ...
# 43875  258907    2019-12-01  8407343009
# 43876  258908    2019-12-01  8407343009
# 43877  258909    2019-12-01  8407343009
# 43878  258910    2019-12-01  8407343009
# 43879  258942    2019-12-01  8407343009
#
#                                      Product Description  \
# 40137  ДВС ОТ А/М, Б/У, В СБОРЕ С КПП, БЕНЗИН: SUBARU...
# 40139  ДВИГАТЕЛИ ВНУТРЕННЕГО СГОРАНИЯ С ИСКРОВЫМ ЗАЖИ...
# 40140  ЗАП.ЧАСТИ ДЛЯ А/М, Б/У ДВИГАТЕЛЯ С АКП ЯПОНСКО...
# 40142  ДВИГАТ.БЕНЗ.-17ШТ,С НАВЕС.ОБОРУД.ДЛЯ Л/А,МАССО...
# 40143  ДВИГАТЕЛИ-10ШТ, БЫВШ. В УПОТР. КАРБЮР. ОБЪЕМ 1...
# ...                                                  ...
# 43875  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43876  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43877  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43878  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43879  ДВИГАТЕЛИ БЕНЗИНОВЫЕ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
#
#                                                 Producer  \
# 40137                      SUBARU, NISSAN, TOYOTA, HONDA
# 40139          TOYOTA, NISSAN, HONDA, MITSUBISHI, SUBARU
# 40140                           TOYOTA,MITSUBISHI,SUBARU
# 40142  HONDA MOTOR COPMANY,MITSUBISHU MOTOR CORPORATI...
# 40143  TOYOTA MOTOR CO.,NISSAN MOTOR CO.,FUJI HEAVY I...
# ...                                                  ...
# 43875                                             SUBARU
# 43876                                             SUBARU
# 43877                                             SUBARU
# 43878                                             SUBARU
# 43879                                 SUBARU CORPORATION
#
#                                            Brand Place of Receipt  \
# 40137              SUBARU, NISSAN, TOYOTA, HONDA      ВЛАДИВОСТОК
# 40139  TOYOTA, NISSAN, HONDA, MITSUBISHI, SUBARU      ВЛАДИВОСТОК
# 40140                   TOYOTA,MITSUBISHI,SUBARU      ВЛАДИВОСТОК
# 40142      HONDA,MITSUBISHU,NISSAN,TOYOTA,SUBARU        ВОСТОЧНЫЙ
# 40143                      TOYOTA,NISSAN,SUBARU.        ВОСТОЧНЫЙ
# ...                                          ...              ...
# 43875                                     SUBARU      ВЛАДИВОСТОК
# 43876                                     SUBARU      ВЛАДИВОСТОК
# 43877                                     SUBARU      ВЛАДИВОСТОК
# 43878                                     SUBARU      ВЛАДИВОСТОК
# 43879                                     SUBARU      ВЛАДИВОСТОК
#
#       Country of Origin Country of Sales                            Shipper   \
# 40137    JP, JPN, Japan   JP, JPN, Japan               G.E. TRADING CO., LTD
# 40139    JP, JPN, Japan   JP, JPN, Japan  J & A TRADING CORPORATION PVT, LTD
# 40140    JP, JPN, Japan   JP, JPN, Japan              АВТОЛОМ ДЖАПАН КО.,ЛТД
# 40142    JP, JPN, Japan   JP, JPN, Japan             TATSUMI SHOKAI CO.,LTD.
# 40143    JP, JPN, Japan     CT, , Taiwan                    SUNTEC CO., LTD.
# ...                 ...              ...                                 ...
# 43875    JP, JPN, Japan   JP, JPN, Japan                     D-JAPAN CO. LTD
# 43876    JP, JPN, Japan   JP, JPN, Japan                     D-JAPAN CO. LTD
# 43877    JP, JPN, Japan   JP, JPN, Japan                     D-JAPAN CO. LTD
# 43878    JP, JPN, Japan   JP, JPN, Japan                     D-JAPAN CO. LTD
# 43879    JP, JPN, Japan   JP, JPN, Japan                           AL EXPORT
#
#        ... Incoterms Gross Weight in KG Net Weight in KG  Cargo Value USD  \
# 40137  ...       CFR             3250.0           3250.0          3250.00
# 40139  ...       CFR             7800.0           7800.0          2100.00
# 40140  ...       CFR              600.0            600.0           480.00
# 40142  ...       CFR             3860.0           3860.0          5790.00
# 40143  ...       CFR             2686.6           2686.6          3228.26
# ...    ...       ...                ...              ...              ...
# 43875  ...       CFR              200.0            200.0           302.00
# 43876  ...       CFR              200.0            200.0           302.00
# 43877  ...       CFR              200.0            200.0           302.00
# 43878  ...       CFR              200.0            200.0           302.00
# 43879  ...       CFR              220.0            220.0           332.20
#
#       extracted_engine   brand  month_year  year  len_unique_em len_em
# 40137     [EJ20, EJ20]  SUBARU     2011-01  2011              1      2
# 40139           [EJ20]  SUBARU     2011-01  2011              1      1
# 40140           [EJ20]  SUBARU     2011-01  2011              1      1
# 40142     [EJ20, EJ20]  SUBARU     2011-01  2011              1      2
# 40143           [EJ20]  SUBARU     2011-02  2011              1      1
# ...                ...     ...         ...   ...            ...    ...
# 43875           [EJ20]  SUBARU     2019-12  2019              1      1
# 43876           [EJ20]  SUBARU     2019-12  2019              1      1
# 43877           [EJ20]  SUBARU     2019-12  2019              1      1
# 43878           [EJ20]  SUBARU     2019-12  2019              1      1
# 43879           [EJ20]  SUBARU     2019-12  2019              1      1
#
# [2878 rows x 25 columns]

# %%
df_3s['count_em']  = df_3s['extracted_engine'].map(lambda x: count_length(x,'EJ20') )
# Out:
# <ipython-input-26-217524a0fd61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3s['count_em']  = df_3s['extracted_engine'].map(lambda x: count_length(x,'EJ20') )

# %%
unit_price = df_3s[(df_3s.Quantity == 1) & (df_3s.count_em==1)].describe().loc[('mean','Cargo Value USD')]
unit_price
# Out:
# 227.51370517928285

# %%
df_3s['Quantity'] = df_3s.apply(lambda x : normalize_zero (x,unit_price), axis=1)
# Out:
# <ipython-input-28-138da5abc9fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3s['Quantity'] = df_3s.apply(lambda x : normalize_zero (x,unit_price), axis=1)

# %%
df_3s.describe()
# Out:
#                index       HS Code     Quantity  Gross Weight in KG  \
# count    2878.000000  2.878000e+03  2878.000000         2878.000000
# mean   141696.849548  8.407343e+09     5.753301         1144.873822
# std     75745.370585  1.491230e-01     6.694974         1265.812860
# min        20.000000  8.407343e+09     0.000000           80.000000
# 25%     80846.750000  8.407343e+09     1.000000          280.000000
# 50%    134313.000000  8.407343e+09     3.000000          680.000000
# 75%    217873.000000  8.407343e+09     8.000000         1500.000000
# max    258942.000000  8.407343e+09    66.000000        11330.000000
#
#        Net Weight in KG  Cargo Value USD  len_unique_em       len_em  \
# count       2878.000000      2878.000000    2878.000000  2878.000000
# mean        1144.582147      1469.606935       1.321056     2.143502
# std         1265.633981      1656.968850       0.586413     1.604622
# min           80.000000        42.650000       1.000000     1.000000
# 25%          280.000000       391.760000       1.000000     1.000000
# 50%          680.000000       768.000000       1.000000     1.000000
# 75%         1500.000000      1965.000000       2.000000     3.000000
# max        11330.000000     14073.200000       5.000000    12.000000
#
#           count_em
# count  2878.000000
# mean      1.747741
# std       1.250215
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max      10.000000

# %%
df_3s['total_price'] = df_3s.apply(lambda x : check_count_em(x,unit_price),axis=1)
# df_3s.drop(columns = ['total_price_1nz'],inplace = True)
# Out:
# <ipython-input-30-097b22d29e78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3s['total_price'] = df_3s.apply(lambda x : check_count_em(x,unit_price),axis=1)

# %%
df_3s
# Out:
#         index Register Date     HS Code  \
# 40137      20    2011-01-25  8407343009
# 40139      35    2011-01-12  8407343009
# 40140      91    2011-01-21  8407343009
# 40142    1011    2011-01-25  8407343009
# 40143    1483    2011-02-07  8407343009
# ...       ...           ...         ...
# 43875  258907    2019-12-01  8407343009
# 43876  258908    2019-12-01  8407343009
# 43877  258909    2019-12-01  8407343009
# 43878  258910    2019-12-01  8407343009
# 43879  258942    2019-12-01  8407343009
#
#                                      Product Description  \
# 40137  ДВС ОТ А/М, Б/У, В СБОРЕ С КПП, БЕНЗИН: SUBARU...
# 40139  ДВИГАТЕЛИ ВНУТРЕННЕГО СГОРАНИЯ С ИСКРОВЫМ ЗАЖИ...
# 40140  ЗАП.ЧАСТИ ДЛЯ А/М, Б/У ДВИГАТЕЛЯ С АКП ЯПОНСКО...
# 40142  ДВИГАТ.БЕНЗ.-17ШТ,С НАВЕС.ОБОРУД.ДЛЯ Л/А,МАССО...
# 40143  ДВИГАТЕЛИ-10ШТ, БЫВШ. В УПОТР. КАРБЮР. ОБЪЕМ 1...
# ...                                                  ...
# 43875  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43876  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43877  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43878  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43879  ДВИГАТЕЛИ БЕНЗИНОВЫЕ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
#
#                                                 Producer  \
# 40137                      SUBARU, NISSAN, TOYOTA, HONDA
# 40139          TOYOTA, NISSAN, HONDA, MITSUBISHI, SUBARU
# 40140                           TOYOTA,MITSUBISHI,SUBARU
# 40142  HONDA MOTOR COPMANY,MITSUBISHU MOTOR CORPORATI...
# 40143  TOYOTA MOTOR CO.,NISSAN MOTOR CO.,FUJI HEAVY I...
# ...                                                  ...
# 43875                                             SUBARU
# 43876                                             SUBARU
# 43877                                             SUBARU
# 43878                                             SUBARU
# 43879                                 SUBARU CORPORATION
#
#                                            Brand Place of Receipt  \
# 40137              SUBARU, NISSAN, TOYOTA, HONDA      ВЛАДИВОСТОК
# 40139  TOYOTA, NISSAN, HONDA, MITSUBISHI, SUBARU      ВЛАДИВОСТОК
# 40140                   TOYOTA,MITSUBISHI,SUBARU      ВЛАДИВОСТОК
# 40142      HONDA,MITSUBISHU,NISSAN,TOYOTA,SUBARU        ВОСТОЧНЫЙ
# 40143                      TOYOTA,NISSAN,SUBARU.        ВОСТОЧНЫЙ
# ...                                          ...              ...
# 43875                                     SUBARU      ВЛАДИВОСТОК
# 43876                                     SUBARU      ВЛАДИВОСТОК
# 43877                                     SUBARU      ВЛАДИВОСТОК
# 43878                                     SUBARU      ВЛАДИВОСТОК
# 43879                                     SUBARU      ВЛАДИВОСТОК
#
#       Country of Origin Country of Sales                            Shipper   \
# 40137    JP, JPN, Japan   JP, JPN, Japan               G.E. TRADING CO., LTD
# 40139    JP, JPN, Japan   JP, JPN, Japan  J & A TRADING CORPORATION PVT, LTD
# 40140    JP, JPN, Japan   JP, JPN, Japan              АВТОЛОМ ДЖАПАН КО.,ЛТД
# 40142    JP, JPN, Japan   JP, JPN, Japan             TATSUMI SHOKAI CO.,LTD.
# 40143    JP, JPN, Japan     CT, , Taiwan                    SUNTEC CO., LTD.
# ...                 ...              ...                                 ...
# 43875    JP, JPN, Japan   JP, JPN, Japan                     D-JAPAN CO. LTD
# 43876    JP, JPN, Japan   JP, JPN, Japan                     D-JAPAN CO. LTD
# 43877    JP, JPN, Japan   JP, JPN, Japan                     D-JAPAN CO. LTD
# 43878    JP, JPN, Japan   JP, JPN, Japan                     D-JAPAN CO. LTD
# 43879    JP, JPN, Japan   JP, JPN, Japan                           AL EXPORT
#
#        ... Net Weight in KG Cargo Value USD extracted_engine   brand  \
# 40137  ...           3250.0         3250.00     [EJ20, EJ20]  SUBARU
# 40139  ...           7800.0         2100.00           [EJ20]  SUBARU
# 40140  ...            600.0          480.00           [EJ20]  SUBARU
# 40142  ...           3860.0         5790.00     [EJ20, EJ20]  SUBARU
# 40143  ...           2686.6         3228.26           [EJ20]  SUBARU
# ...    ...              ...             ...              ...     ...
# 43875  ...            200.0          302.00           [EJ20]  SUBARU
# 43876  ...            200.0          302.00           [EJ20]  SUBARU
# 43877  ...            200.0          302.00           [EJ20]  SUBARU
# 43878  ...            200.0          302.00           [EJ20]  SUBARU
# 43879  ...            220.0          332.20           [EJ20]  SUBARU
#
#       month_year  year  len_unique_em  len_em  count_em total_price
# 40137    2011-01  2011              1       2         2   455.02741
# 40139    2011-01  2011              1       1         1  2100.00000
# 40140    2011-01  2011              1       1         1   480.00000
# 40142    2011-01  2011              1       2         2   455.02741
# 40143    2011-02  2011              1       1         1  3228.26000
# ...          ...   ...            ...     ...       ...         ...
# 43875    2019-12  2019              1       1         1   302.00000
# 43876    2019-12  2019              1       1         1   302.00000
# 43877    2019-12  2019              1       1         1   302.00000
# 43878    2019-12  2019              1       1         1   302.00000
# 43879    2019-12  2019              1       1         1   332.20000
#
# [2878 rows x 27 columns]

# %%
df_3s[df_3s.total_price> df_3s['Cargo Value USD']]
# Out:
# Empty DataFrame
# Columns: [index, Register Date, HS Code, Product Description, Producer, Brand, Place of Receipt, Country of Origin, Country of Sales, Shipper , Shipper Address, Consignee, Consignee Address, Quantity, Unit of Measure, Incoterms, Gross Weight in KG, Net Weight in KG, Cargo Value USD, extracted_engine, brand, month_year, year, len_unique_em, len_em, count_em, total_price]
# Index: []
#
# [0 rows x 27 columns]

# %%
df_sum_day = df_3s.groupby(['Register Date'])['total_price'].sum().reset_index()
df_sum_month = df_3s.groupby(['month_year'])['total_price'].sum().reset_index()
df_sum_year = df_3s.groupby(['year'])['total_price'].sum().reset_index()
df_sum_month['month_year'] = pd.to_datetime(df_sum_month['month_year'],format='%Y-%m')
df_sum_month.set_index('month_year',inplace = True)
# df_sum_day['Register Date'] = df_sum_day['Register Date'].astype(str)
df_sum_year['year'] = pd.to_datetime(df_sum_year['year'],format='%Y')
em_series_month =  pd.Series(df_sum_month.total_price.values,index=df_sum_month.index)
em_series_year =  pd.Series(df_sum_year.total_price.values,index=df_sum_year['year'])

# %%
em_series_month.index
# Out:
# DatetimeIndex(['2011-01-01', '2011-02-01', '2011-03-01', '2011-04-01',
#                '2011-05-01', '2011-06-01', '2011-07-01', '2011-08-01',
#                '2011-10-01', '2011-11-01', '2011-12-01', '2012-01-01',
#                '2012-02-01', '2012-03-01', '2012-04-01', '2012-05-01',
#                '2012-06-01', '2012-07-01', '2012-08-01', '2012-09-01',
#                '2012-10-01', '2012-11-01', '2012-12-01', '2013-01-01',
#                '2013-02-01', '2013-04-01', '2013-06-01', '2013-07-01',
#                '2013-08-01', '2013-09-01', '2013-10-01', '2013-11-01',
#                '2013-12-01', '2014-01-01', '2014-02-01', '2014-03-01',
#                '2014-04-01', '2014-05-01', '2014-06-01', '2014-07-01',
#                '2014-08-01', '2014-09-01', '2014-10-01', '2014-11-01',
#                '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01',
#                '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01',
#                '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01',
#                '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01',
#                '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01',
#                '2016-08-01', '2016-09-01', '2016-10-01', '2017-03-01',
#                '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01',
#                '2017-08-01', '2017-09-01', '2017-10-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='month_year', freq=None)

# %%
em_series = pd.Series(df_sum_day.total_price.values,index=df_sum_day['Register Date'])
em_series_sample = pd.Series(df_3s.total_price.values,index=df_3s['Register Date'])
# em_series.index = em_series.index.to_period('M')
# em_series.to_csv('toyota_1nz.csv')

# %%
plt.figure(figsize=(15,8))
values = em_series.values
# plot dataset
sns.lineplot(data=em_series.resample('MS').sum())
# Out:
# <AxesSubplot:xlabel='Register Date'>

# %%
em_series_month.index
# Out:
# DatetimeIndex(['2011-01-01', '2011-02-01', '2011-03-01', '2011-04-01',
#                '2011-05-01', '2011-06-01', '2011-07-01', '2011-08-01',
#                '2011-10-01', '2011-11-01', '2011-12-01', '2012-01-01',
#                '2012-02-01', '2012-03-01', '2012-04-01', '2012-05-01',
#                '2012-06-01', '2012-07-01', '2012-08-01', '2012-09-01',
#                '2012-10-01', '2012-11-01', '2012-12-01', '2013-01-01',
#                '2013-02-01', '2013-04-01', '2013-06-01', '2013-07-01',
#                '2013-08-01', '2013-09-01', '2013-10-01', '2013-11-01',
#                '2013-12-01', '2014-01-01', '2014-02-01', '2014-03-01',
#                '2014-04-01', '2014-05-01', '2014-06-01', '2014-07-01',
#                '2014-08-01', '2014-09-01', '2014-10-01', '2014-11-01',
#                '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01',
#                '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01',
#                '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01',
#                '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01',
#                '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01',
#                '2016-08-01', '2016-09-01', '2016-10-01', '2017-03-01',
#                '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01',
#                '2017-08-01', '2017-09-01', '2017-10-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='month_year', freq=None)

# %%
decomposition = seasonal_decompose(em_series_month, model='additive',period = 2)
plt.figure(figsize=(12,8))
plt.xticks(fontsize = 20, rotation = 0)
plt.yticks(fontsize = 20, rotation = 0)
plt.xlabel('Year',fontsize = 20)
plt.ylabel('value',fontsize = 20)
plt.plot(decomposition.trend)

# %%
def series_to_supervised(data, n_in=4, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols = list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
	# put it all together
	agg = pd.concat(cols, axis=1)
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg.values

# %%
names = ["Gradient_Boosting", "Decision_Tree", "Extra_Trees", "Random_Forest","LGBM","XGBoost"]
models = [
    GradientBoostingRegressor(),
    DecisionTreeRegressor(max_depth=5),
    ExtraTreesRegressor(),
    RandomForestRegressor(),
    LGBMRegressor(),
    XGBRegressor()]

# %%
# values = pd.DataFrame(em_series.values)
# dataframe = pd.concat([values.shift(1), values], axis=1)
# dataframe.columns = ['t-1', 't']
# dataframe.dropna(inplace= True)
# target = dataframe.iloc[:,1]
# data = dataframe.iloc[:,:-1]
dataset = series_to_supervised(np.expand_dims(em_series_sample.values,axis=1), n_in=1)
data  = dataset[:,:-1]
target = dataset[:,-1]

# %%
# split into train and test sets
size = int(len(em_series_sample) * 0.7)
train_X, test_X = data[0:size], data[size:len(em_series_sample)]
train_y, test_y = target[0:size], target[size:len(em_series_sample)]
model = XGBRegressor(objective='reg:squarederror', n_estimators=1000)
# model = XGBRegressor()
# model = LGBMRegressor()
model.fit(train_X, train_y)
yhat = model.predict(test_X)
rmse = mean_squared_error(test_y, yhat,squared=False)
mape = mean_absolute_percentage_error(test_y, yhat)
print('Test RMSE: %.3f' % rmse)
print('Test MAPE: %.3f' % mape)
# Out:
# Test RMSE: 1119.956
# Test MAPE: 1.412

# %%
rmse = []
mape = []
r_squared = []
for  model in models:
    model.fit(train_X, train_y)
    y_pred  = model.predict(test_X)
#     print(y_pred)
    rmse_score = mean_squared_error(test_y, y_pred,squared=False)
    mape_score = np.mean(np.abs((test_y - y_pred)/test_y)*100)
    r_squared_score  = model.score(test_X,test_y)
    r_squared.append(r_squared_score)
    rmse.append(rmse_score)
    mape.append(mape_score)

# %%
df_score = pd.DataFrame()
df_score['MODELS'] = names
df_score['R_SQUARED'] = r_squared
df_score['RMSE'] = rmse
df_score['MAPE'] = mape
df_score['RMSE'] = round(df_score['RMSE'],3)
df_score['MAPE'] = round(df_score['MAPE'],3)
df_score['R_SQUARED'] = round(df_score['R_SQUARED'],3)

df_score
# Out:
#               MODELS  R_SQUARED      RMSE     MAPE
# 0  Gradient_Boosting     -0.625   545.717  117.413
# 1      Decision_Tree     -0.767   569.101  126.883
# 2        Extra_Trees     -4.833  1033.927  139.145
# 3      Random_Forest     -2.741   828.093  120.906
# 4               LGBM     -0.610   543.268  107.697
# 5            XGBoost     -3.115   868.498  127.858

# %%
plt.figure(figsize=(15,8))
plt.plot(test_y, label='Expected')
plt.plot(yhat, label='Predicted')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

X = np.log(em_series).values
size = int(len(X) * 0.7)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
# rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
# mape = mean_absolute_percentage_error(y_truth, y_forecasted)
rmse = mean_squared_error(np.exp(test), np.exp(predictions),squared=False)
mape = mean_absolute_percentage_error(np.exp(test), np.exp(predictions))
print('Test RMSE: %.3f' % rmse)
print('Test MAPE: %.3f' % mape)
# plot forecasts against actual outcomes
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=7.839284, expected=8.131616
# predicted=7.952912, expected=6.796824
# predicted=7.842370, expected=6.889082
# predicted=7.720239, expected=5.827474
# predicted=7.323618, expected=7.615397
# predicted=7.168293, expected=7.572956
# predicted=7.038269, expected=7.843621
# predicted=7.098860, expected=7.741968
# predicted=7.266747, expected=8.957205
# predicted=7.701895, expected=8.475848
# predicted=8.076242, expected=7.978369
# predicted=8.158085, expected=8.498520
# predicted=8.279894, expected=8.211993
# predicted=8.352073, expected=8.083329
# predicted=8.323725, expected=6.834980
# predicted=7.997676, expected=7.659143
# predicted=7.851116, expected=6.257041
# predicted=7.512491, expected=7.588324
# predicted=7.337456, expected=7.446807
# predicted=7.243982, expected=8.605255
# predicted=7.429178, expected=8.061487
# predicted=7.639326, expected=6.257041
# predicted=7.493578, expected=7.718685
# predicted=7.587558, expected=7.046734
# predicted=7.520731, expected=7.758120
# predicted=7.478267, expected=8.434650
# predicted=7.499120, expected=7.095355
# predicted=7.507203, expected=8.707814
# predicted=7.773971, expected=7.390181
# predicted=7.817073, expected=7.122867
# predicted=7.770287, expected=6.404286
# predicted=7.440805, expected=7.695594
# predicted=7.393033, expected=7.902487
# predicted=7.438968, expected=6.257041
# predicted=7.146072, expected=7.261927
# predicted=7.086480, expected=8.277633
# predicted=7.347374, expected=6.514713
# predicted=7.322033, expected=6.514713
# predicted=7.076598, expected=6.514713
# predicted=6.933345, expected=6.942118
# predicted=6.962389, expected=7.886837
# predicted=6.987845, expected=7.741968
# predicted=7.070465, expected=7.090077
# predicted=7.185920, expected=8.282733
# predicted=7.474450, expected=8.676424
# predicted=7.836621, expected=7.362011
# predicted=7.865658, expected=6.985133
# predicted=7.703026, expected=8.310169
# predicted=7.819770, expected=6.996242
# predicted=7.718996, expected=7.625083
# predicted=7.578041, expected=6.257041
# predicted=7.261040, expected=6.552665
# predicted=7.123144, expected=6.257041
# predicted=6.860443, expected=8.917041
# predicted=7.062101, expected=5.563894
# predicted=6.870804, expected=6.662506
# predicted=6.744246, expected=7.918945
# predicted=6.978505, expected=7.299797
# predicted=7.134718, expected=6.257041
# predicted=7.018680, expected=8.180847
# predicted=7.074886, expected=8.210608
# predicted=7.426867, expected=6.729824
# predicted=7.425284, expected=8.086410
# predicted=7.520978, expected=6.025479
# predicted=7.339840, expected=8.149024
# predicted=7.462830, expected=8.748305
# predicted=7.562682, expected=6.833732
# predicted=7.516286, expected=7.528332
# predicted=7.583306, expected=7.544332
# predicted=7.560023, expected=8.570929
# predicted=7.816882, expected=8.300280
# predicted=7.842945, expected=8.101678
# predicted=7.913033, expected=7.864020
# predicted=8.046924, expected=8.268732
# predicted=8.144044, expected=7.583110
# predicted=8.084505, expected=7.847751
# predicted=7.975783, expected=8.475687
# predicted=7.993310, expected=8.308150
# predicted=8.055883, expected=8.956725
# predicted=8.230747, expected=8.673665
# predicted=8.370238, expected=8.939291
# predicted=8.593399, expected=9.504352
# predicted=8.826791, expected=8.695062
# predicted=8.903073, expected=8.530384
# predicted=8.907011, expected=9.288084
# predicted=8.944025, expected=8.477951
# predicted=8.895296, expected=9.650299
# predicted=8.971336, expected=8.830439
# predicted=8.934657, expected=9.039331
# predicted=9.016936, expected=9.124557
# predicted=9.051876, expected=9.519157
# predicted=9.136838, expected=9.322360
# predicted=9.215696, expected=9.138779
# predicted=9.205634, expected=9.765378
# predicted=9.331957, expected=9.607162
# predicted=9.425571, expected=6.257041
# Test RMSE: 2765.918
# Test MAPE: 1.028

# %%
X = em_series.values
size = int(len(X) * 0.7)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
# predictions = list()
# # walk-forward validation
# for t in range(len(test)):
# 	model = ARIMA(history, order=(5,1,1))
# 	model_fit = model.fit()
# 	output = model_fit.forecast()
# 	yhat = output[0]
# 	predictions.append(yhat)
# 	obs = test[t]
# 	history.append(obs)
# 	print('predicted=%f, expected=%f' % (yhat, obs))
# # evaluate forecasts
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# rmse = mean_squared_error(np.exp(test), np.exp(predictions),squared=False)
# mape = mean_absolute_percentage_error(np.exp(test), np.exp(predictions))
# print('RMSE: %.3f' % rmse)
# print('MAPE: %.3f' % mape)
model = ARIMA(em_series, order=(1,1,1))
results = model.fit()
pred = results.predict(start='2017-01', dynamic=False)
y_forecasted = pred
y_truth = em_series['2017-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# plot forecasts against actual outcomes
plt.plot(y_forecasted)
plt.plot(y_truth, color='red')
plt.show()
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# RMSE: 4838.685
# MAPE: 1.310

# %%
plt.figure(figsize=(12,8))
# plt.plot(np.exp(predictions), color='red')
# plt.xticks(rotation = 90)
# sns.lineplot(x=list(df_sum_month['month_year'][size:len(X)]),y=np.exp(test),data=np.exp(test))
# plt.legend(loc='upper left', labels=['forecast','test'])
plt.plot(np.exp(test))
plt.plot(np.exp(predictions), color='red')
plt.show()
# Out:
# <ipython-input-56-ba1bbbfd531d>:6: RuntimeWarning: overflow encountered in exp
#   plt.plot(np.exp(test))

# %%
X = np.log(em_series_sample).values
size = int(len(X) * 0.7)
train, test = X[0:size], X[size:len(X)]
# history = [x for x in train]
# predictions = list()
# # walk-forward validation
# for t in range(len(test)):
# 	model = ARIMA(history, order=(5,1,0))
# 	model_fit = model.fit()
# 	output = model_fit.forecast()
# 	yhat = output[0]
# 	predictions.append(yhat)
# 	obs = test[t]
# 	history.append(obs)
# 	print('predicted=%f, expected=%f' % (yhat, obs))
# # evaluate forecasts
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA')
# rmse = mean_squared_error(np.exp(test), np.exp(predictions),squared=False)
# mape = mean_absolute_percentage_error(np.exp(test), np.exp(predictions))
# print('RMSE: %.3f' % rmse)
# print('MAPE: %.3f' % mape)
model = ARIMA(em_series_sample, order=(4,1,1))
results = model.fit()
pred = results.predict(start='2017-01-01', dynamic=False)
y_forecasted = pred
y_truth = em_series['2017-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# plot forecasts against actual outcomes
plt.plot(y_forecasted)
plt.plot(y_truth, color='red')
plt.show()

# plot forecasts against actual outcomes
# plt.plot(test)
# plt.plot(predictions, color='red')
# plt.show()
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py in get_index_label_loc(key, index, row_labels)
#     248                 else:
# --> 249                     loc = loc[0]
#     250             if not isinstance(loc, numbers.Integral):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     323     try:
# --> 324         start, _, start_oos = get_index_label_loc(start, base_index, data.row_labels)
#     325     except KeyError:
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py in get_index_label_loc(key, index, row_labels)
#     255         except:
# --> 256             raise e
#     257     return loc, index, index_was_expanded
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py in get_index_label_loc(key, index, row_labels)
#     219     try:
# --> 220         loc, index, index_was_expanded = get_index_loc(key, index)
#     221     except KeyError as e:
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py in get_index_loc(key, index)
#     169         except (IndexError, ValueError) as e:
# --> 170             raise KeyError(str(e))
#     171         loc = key
#
# KeyError: 'only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-621e345a4c07> in <module>
#      22 model = ARIMA(em_series_sample, order=(4,1,1))
#      23 results = model.fit()
# ---> 24 pred = results.predict(start='2017-01-01', dynamic=False)
#      25 y_forecasted = pred
#      26 y_truth = em_series['2017-01-01':]
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\wrapper.py in wrapper(self, *args, **kwargs)
#     111             obj = data.wrap_output(func(results, *args, **kwargs), how[0], how[1:])
#     112         elif how:
# --> 113             obj = data.wrap_output(func(results, *args, **kwargs), how)
#     114         return obj
#     115
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in predict(self, start, end, dynamic, **kwargs)
#    3386         """
#    3387         # Perform the prediction
# -> 3388         prediction_results = self.get_prediction(start, end, dynamic, **kwargs)
#    3389         return prediction_results.predicted_mean
#    3390
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in get_prediction(self, start, end, dynamic, index, exog, extend_model, extend_kwargs, **kwargs)
#    3284         # Handle start, end, dynamic
#    3285         start, end, out_of_sample, prediction_index = (
# -> 3286             self.model._get_prediction_index(start, end, index))
#    3287
#    3288         # Handle `dynamic`
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py in _get_prediction_index(self, start, end, index, silent)
#     736         """
#     737         nobs = len(self.endog)
# --> 738         return get_prediction_index(start,
#     739                                     end,
#     740                                     nobs,
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     324         start, _, start_oos = get_index_label_loc(start, base_index, data.row_labels)
#     325     except KeyError:
# --> 326         raise KeyError('The `start` argument could not be matched to a'
#     327                        ' location related to the index of the data.')
#     328     if end is None:
#
# KeyError: 'The `start` argument could not be matched to a location related to the index of the data.'

# %%
plt.figure(figsize=(12,8))
plt.plot(np.exp(test))
plt.plot(np.exp(predictions), color='red')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(np.exp(predictions), color='red')
plt.xticks(rotation = 90)
sns.lineplot(x=list(df_sum_day['Register Date'][size:len(X)]),y=np.exp(test),data=np.exp(test))
plt.legend(loc='upper left', labels=['forecast','test'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-8e8496804374> in <module>
#       2 plt.plot(np.exp(predictions), color='red')
#       3 plt.xticks(rotation = 90)
# ----> 4 sns.lineplot(x=list(df_sum_day['Register Date'][size:len(X)]),y=np.exp(test),data=np.exp(test))
#       5 plt.legend(loc='upper left', labels=['forecast','test'])
#
# D:\Software\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\Software\Anaconda\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     683
#     684     variables = _LinePlotter.get_semantics(locals())
# --> 685     p = _LinePlotter(
#     686         data=data, variables=variables,
#     687         estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
#
# D:\Software\Anaconda\lib\site-packages\seaborn\relational.py in __init__(self, data, variables, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     365         )
#     366
# --> 367         super().__init__(data=data, variables=variables)
#     368
#     369         self.estimator = estimator
#
# D:\Software\Anaconda\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# D:\Software\Anaconda\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# D:\Software\Anaconda\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     890
#     891                 if val in data:
# --> 892                     plot_data[key] = data[val]
#     893                 elif val in index:
#     894                     plot_data[key] = index[val]
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
X = np.log(em_series_month).values
size = int(len(X) * 0.70)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# model = ARIMA(np.log(em_series_month), order=(5,1,0))
# results = model.fit()
# pred = results.predict(start='2017-01', dynamic=False)
# y_forecasted = np.exp(pred)
# y_truth = em_series_month['2017-01-01':]
# rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
# mape = mean_absolute_percentage_error(y_truth, y_forecasted)
# print('RMSE: %.3f' % rmse)
# print('MAPE: %.3f' % mape)
# # plot forecasts against actual outcomes
# plt.xticks(rotation = 90)
# plt.plot(y_forecasted,color='red')
# plt.plot(em_series_month)
# plt.show()
#walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,0,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))
# evaluate forecasts
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)
rmse = mean_squared_error(np.exp(test), np.exp(predictions),squared=False)
mape = mean_absolute_percentage_error(np.exp(test), np.exp(predictions))
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=19795.573977, expected=12664.147809
# predicted=13010.199537, expected=10357.848207
# predicted=21638.516533, expected=12114.208924
# predicted=12903.535669, expected=21486.006375
# predicted=14880.316218, expected=21215.048566
# predicted=15073.592735, expected=27930.317849
# predicted=20783.203007, expected=22946.879681
# predicted=18924.571503, expected=41450.700040
# predicted=25591.684774, expected=24976.433785
# predicted=20335.457237, expected=29030.935618
# predicted=29073.579582, expected=37148.979363
# predicted=22737.449769, expected=53075.100080
# predicted=28651.457922, expected=36153.096375
# predicted=29203.360787, expected=15931.395259
# predicted=28348.905517, expected=50735.097171
# predicted=30513.503186, expected=39607.357092
# predicted=20099.422912, expected=25894.978924
# predicted=33869.165674, expected=36710.824542
# predicted=29066.306648, expected=37931.525618
# predicted=25852.931312, expected=33277.684900
# predicted=30344.969752, expected=44566.618566
# predicted=31768.612816, expected=54113.472032
# predicted=32169.411998, expected=39635.020120
# predicted=35424.133145, expected=28970.742271
# predicted=35584.659753, expected=46261.900438
# predicted=34440.491191, expected=38584.220438
# predicted=28988.086795, expected=36317.931155
# RMSE: 12136.329
# MAPE: 0.321

# %%
# plt.xticks(rotation = 90)
# plt.plot_date(df_sum_month['month_year'][size:len(X)], np.exp(predictions))
# list_time_test = list(df_sum_month['month_year'][size:len(X)])
# list_time_test

df_sum_month.reset_index(inplace=True)
df_sum_month['month_year'] = df_sum_month['month_year'].astype(str)
list_datetime = list(df_sum_month['month_year'][size:len(X)])
# # list_datetime = list(df_sum_month.reset_index()['month_year'][size:len(X)])
list_datetime
# df_sum_month[df_sum_month['month_year'].map(lambda x: '2017' in x)]
# Out:
# ['2016-05-01',
#  '2016-06-01',
#  '2016-07-01',
#  '2016-08-01',
#  '2016-09-01',
#  '2016-10-01',
#  '2017-03-01',
#  '2017-04-01',
#  '2017-05-01',
#  '2017-06-01',
#  '2017-07-01',
#  '2017-08-01',
#  '2017-09-01',
#  '2017-10-01',
#  '2018-12-01',
#  '2019-01-01',
#  '2019-02-01',
#  '2019-03-01',
#  '2019-04-01',
#  '2019-05-01',
#  '2019-06-01',
#  '2019-07-01',
#  '2019-08-01',
#  '2019-09-01',
#  '2019-10-01',
#  '2019-11-01',
#  '2019-12-01']

# %%
plt.figure(figsize=(12,8))
plt.plot(np.exp(predictions), color='red')
plt.xticks(rotation = 90)
plt.xlabel('Month')
plt.ylabel('revenue')
sns.lineplot(x=list_datetime,y='total_price',data=df_sum_month[size:len(X)])
plt.legend(loc='upper left', labels=['forecast','test'])

# plt.figure(figsize=(12,8))
# plt.plot(np.exp(predictions), color='red')
# plt.plot(em_series_month)
# plt.xticks(rotation = 90)
# plt.ylabel('revenue')
# # sns.lineplot(x=list(df_sum_year['year']),y='total_price_1g',data=df_sum_year)
# plt.legend(loc='best', labels=['forecast','test'])

# %%
X = em_series_month.values
size = int(len(X) * 0.7)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# model = ARIMA(np.log(em_series_month), order=(5,1,0))
# results = model.fit()
# pred = results.predict(start='2017-01', dynamic=False)
# y_forecasted = np.exp(pred)
# y_truth = em_series_month['2017-01-01':]
# rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
# mape = mean_absolute_percentage_error(y_truth, y_forecasted)
# print('RMSE: %.3f' % rmse)
# print('MAPE: %.3f' % mape)
# # plot forecasts against actual outcomes
# plt.xticks(rotation = 90)
# plt.plot(y_forecasted,color='red')
# plt.plot(em_series_month)
# plt.show()
#walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,1))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)
rmse = mean_squared_error(test, predictions,squared=False)
mape =mean_absolute_percentage_error(test, predictions)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=22896.123604, expected=12664.147809
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=13972.481128, expected=10357.848207
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=23386.108716, expected=12114.208924
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=12970.691709, expected=21486.006375
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=17128.348736, expected=21215.048566
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=14805.877447, expected=27930.317849
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=20208.468172, expected=22946.879681
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=19133.507092, expected=41450.700040
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=29425.646519, expected=24976.433785
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=23891.609600, expected=29030.935618
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=35440.969873, expected=37148.979363
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=28573.762433, expected=53075.100080
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=35214.212035, expected=36153.096375
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=38404.832854, expected=15931.395259
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=40071.327908, expected=50735.097171
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=41750.455460, expected=39607.357092
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=30105.098447, expected=25894.978924
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=42042.434468, expected=36710.824542
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=36936.235329, expected=37931.525618
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=34646.844640, expected=33277.684900
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=36793.804322, expected=44566.618566
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=38049.576401, expected=54113.472032
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=39062.914928, expected=39635.020120
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=42311.752030, expected=28970.742271
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=45616.510121, expected=46261.900438
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=44338.542010, expected=38584.220438
# predicted=37362.385542, expected=36317.931155
# RMSE: 10302.699
# MAPE: 0.292
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
plt.figure(figsize=(12,8))
plt.plot(predictions, color='red')
plt.xticks(rotation = 90)
plt.xlabel('Month')
plt.ylabel('revenue')
sns.lineplot(x=list_datetime,y='total_price',data=df_sum_month[size:len(X)])
plt.legend(loc='upper left', labels=['forecast','test'])

# %%
em_series_year
# Out:
# year
# 2011-01-01    155024.148287
# 2012-01-01    201477.743068
# 2013-01-01    324477.864143
# 2014-01-01    355049.714821
# 2015-01-01    245029.354582
# 2016-01-01    182043.187968
# 2017-01-01    260713.520199
# 2018-01-01     50735.097171
# 2019-01-01    461872.276096
# dtype: float64

# %%
# X = np.log(em_series_year).values
X = em_series_year.values
# size = int(len(X) * 0.5)
# train, test = X[0:size], X[size:len(X)]
# history = [x for x in train]
model = ARIMA(em_series_year, order=(1,0,1))
results = model.fit()
pred = results.predict(start='2016-01-01', dynamic=False)
y_forecasted = pred
y_truth = em_series_year['2016-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# plot forecasts against actual outcomes
plt.xticks(rotation = 90)
plt.plot(y_forecasted,color='red')
plt.plot(em_series_year)
plt.show()
# predictions = list()|
# # walk-forward validation
# for t in range(len(test)):
# 	model = ARIMA(history, order=(1,1,0))
# 	model_fit = model.fit()
# 	output = model_fit.forecast()
# 	yhat = output[0]
# 	predictions.append(yhat)
# 	obs = test[t]
# 	history.append(obs)
# 	print('predicted=%f, expected=%f' % (yhat, obs))
# # evaluate forecasts
# rmse = mean_squared_error(np.exp(test), np.exp(predictions),squared=False)
# mape = mean_absolute_percentage_error(np.exp(test), np.exp(predictions))
# print('RMSE: %.3f' % rmse)
# print('MAPE: %.3f' % mape)
# # plot forecasts against actual outcomes
# plt.plot(test)
# plt.plot(predictions, color='red')
# plt.show()
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-1a9e1906bc5c> in <module>
#       5 # history = [x for x in train]
#       6 model = ARIMA(em_series_year, order=(1,0,1))
# ----> 7 results = model.fit()
#       8 pred = results.predict(start='2016-01-01', dynamic=False)
#       9 y_forecasted = pred
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1014             start_params = array_like(start_params, 'start_params')
#    1015         else:  # estimate starting parameters
# -> 1016             start_params = self._fit_start_params((k_ar, k_ma, k), method,
#    1017                                                   start_ar_lags)
#    1018
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py in _fit_start_params(self, order, method, start_ar_lags)
#     606                 return -self.loglike_css(params)
#     607
# --> 608             start_params = self._fit_start_params_hr(order, start_ar_lags)
#     609             if self.transparams:
#     610                 start_params = self._invtransparams(start_params)
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py in _fit_start_params_hr(self, order, start_ar_lags)
#     539                     if maxlag >= nobs:
#     540                         maxlag = nobs - 1
# --> 541                     mod = ar_select_order(endog, maxlag, trend='n',
#     542                                           old_names=False).model
#     543                     armod = mod.fit()
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\ar_model.py in ar_select_order(endog, maxlag, ic, glob, trend, seasonal, exog, hold_back, period, missing, old_names)
#    2654     array([1, 2, 9])
#    2655     """
# -> 2656     full_mod = AutoReg(
#    2657         endog,
#    2658         maxlag,
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\ar_model.py in __init__(self, endog, lags, trend, seasonal, exog, hold_back, period, missing, deterministic, old_names)
#     254             self._old_names = True
#     255         self._check_lags()
# --> 256         self._setup_regressors()
#     257         self.nobs = self._y.shape[0]
#     258         self.data.xnames = self.exog_names
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\ar_model.py in _setup_regressors(self)
#     352             lags = self._lags.shape[0]
#     353             nobs = y.shape[0]
# --> 354             raise ValueError(
#     355                 "The model specification cannot be estimated. "
#     356                 "The model contains {0} regressors ({1} trend, "
#
# ValueError: The model specification cannot be estimated. The model contains 7 regressors (0 trend, 0 seasonal, 7 lags) but after adjustment for hold_back and creation of the lags, there are only 2 data points available to estimate parameters.

# %%
# df_sum_year.reset_index(inplace=True)
# df_sum_year['year'] = df_sum_year['year'].astype(str)
list_datetime = list(df_sum_year['year'][size:len(X)])
# # list_datetime = list(df_sum_month.reset_index()['month_year'][size:len(X)])
# list_datetime
list(df_sum_year['year'][6:])
# Out:
# [Timestamp('2017-01-01 00:00:00'),
#  Timestamp('2018-01-01 00:00:00'),
#  Timestamp('2019-01-01 00:00:00')]

# %%
plt.figure(figsize=(12,8))
plt.plot(y_forecasted, color='red')
plt.plot(em_series_year)
# plt.xticks(rotation = 90)
plt.xlabel('Year')
plt.ylabel('revenue')
# sns.lineplot(x=list(df_sum_year['year']),y='total_price_1g',data=df_sum_year)
plt.legend(loc='best', labels=['forecast','test'])

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter for SARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter for SARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
            mod = SARIMAX(em_series_month,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param,param_seasonal,results.aic))
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1982.7833235803098
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1698.1831203577574
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:1665.986991926892
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:1385.7193425808086
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:1683.8362904663777
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1643.5251817513379
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:1403.1813048499891
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:1383.2737938190285
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1924.9525860926606
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:1656.2675250117913
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:1641.4449800331279
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:1360.3671544757278
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1694.124083396273
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:1643.5155538824215
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:1404.458125179162
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:1360.3790268631285
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1863.2215027463812
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1607.1477070476728
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:1670.8674518896369
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:1371.4771271001146
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:1627.5256632942283
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1608.9748548474417
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:1404.7821227605486
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:1367.6246103650928
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1812.6070892418961
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:1560.9806732046275
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:1624.56146562556
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:1326.2488693682646
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:1602.9357790973677
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1562.9136745773305
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:1384.0230967822622
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:1327.3170435283566
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1879.3469720880887
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1625.4454605157873
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:1660.9167899738138
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:1377.3785531912022
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:1625.6731752330238
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1627.9078963205563
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:1381.5190327274374
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:1378.544786689905
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1835.240487578445
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:1584.309362743688
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:1640.3771211023266
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:1347.5592188439505
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:1604.699870182405
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1586.6125822292106
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:1381.5421955526642
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:1348.829217652679
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1848.4009263550306
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1597.5849969069266
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:1655.6647488812678
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:1357.2435756983377
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:1597.7917939583283
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1598.0573255395116
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:1373.7887805646953
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:1359.18935894085
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1813.447408586416
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:1560.8467468864558
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:1620.6831545092186
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:1328.0999538270519
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:1582.7757472498677
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1561.4754873972415
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:1364.1875242888589
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:1329.1348779260666

# %%
mod =SARIMAX(em_series_month,
                                order=(5, 0, 1),
                                seasonal_order=(5, 0, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3248      0.835     -0.389      0.697      -1.962       1.312
# ar.L2         -0.2630      0.564     -0.466      0.641      -1.369       0.843
# ar.L3      -6.882e-05      0.740   -9.3e-05      1.000      -1.450       1.450
# ar.L4          0.4830      0.573      0.843      0.399      -0.639       1.605
# ar.L5         -0.3243      0.478     -0.679      0.497      -1.261       0.612
# ma.L1          0.5830      0.814      0.716      0.474      -1.013       2.179
# ar.S.L12       0.0870      2.098      0.041      0.967      -4.024       4.198
# ar.S.L24       0.6694      0.853      0.785      0.433      -1.003       2.341
# ar.S.L36       0.1649      1.284      0.128      0.898      -2.352       2.682
# ar.S.L48       0.3515      0.203      1.732      0.083      -0.046       0.749
# ar.S.L60       0.3469      0.972      0.357      0.721      -1.559       2.253
# ma.S.L12       0.2666      2.219      0.120      0.904      -4.082       4.615
# sigma2       1.17e+08   3.31e-08   3.54e+15      0.000    1.17e+08    1.17e+08
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-6cfeaa52b7c1> in <module>
# ----> 1 results.plot_diagnostics(figsize=(16, 8))
#       2 plt.show()
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in plot_diagnostics(self, variable, lags, fig, figsize, truncate_endog_names)
#    4282
#    4283         if resid.shape[0] < max(d, lags):
# -> 4284             raise ValueError(
#    4285                 "Length of endogenous variable must be larger the the number "
#    4286                 "of lags used in the model and the number of observations "
#
# ValueError: Length of endogenous variable must be larger the the number of lags used in the model and the number of observations burned in the log-likelihood calculation.

# %%
pred = results.get_prediction(start='2017-01', dynamic=False)
pred_ci = pred.conf_int()

ax = em_series_month['2017-01':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='forecast', color='red', alpha=.7, figsize=(14, 7))

# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Month')
ax.set_ylabel('revenue')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = em_series_month['2017-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted,)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# RMSE: 7527.268
# MAPE: 0.193

# %%
index = pd.to_datetime(['2020-01-01', '2020-02-01','2020-03-01','2020-02-01','2020-04-01','2020-05-01',
                        '2020-06-01','2020-07-01','2020-08-01','2020-09-01','2020-10-01','2020-11-01','2020-12-01',
                       '2021-01-01', '2021-02-01','2021-03-01','2021-02-01','2021-04-01','2021-05-01',
                        '2021-06-01','2021-07-01','2021-08-01','2021-09-01','2021-10-01','2021-11-01','2021-12-01'])
pred_uc = results.get_forecast(steps=len(index),index=index)
pred_ci = pred_uc.conf_int()
ax = em_series_month.plot(label='observed', figsize=(14, 7),)
pred_uc.predicted_mean.plot(ax=ax, label='forecast',color='red')
# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Month')
ax.set_ylabel('revenue')
plt.legend()
plt.show()

# %%
pred_uc.predicted_mean.to_frame()
# Out:
#             predicted_mean
# 2020-01-01    37365.511774
# 2020-02-01    52294.995288
# 2020-03-01    47580.510507
# 2020-02-01    28129.384073
# 2020-04-01    59877.368774
# 2020-05-01    66304.332690
# 2020-06-01    26523.084071
# 2020-07-01    42116.606406
# 2020-08-01    68660.454558
# 2020-09-01    49177.549730
# 2020-10-01    22326.268573
# 2020-11-01    68421.706953
# 2020-12-01    52563.518350
# 2021-01-01    35147.279603
# 2021-02-01    43125.698695
# 2021-03-01    54504.718979
# 2021-02-01    56774.021899
# 2021-04-01    47579.381736
# 2021-05-01    50565.121459
# 2021-06-01    54456.129858
# 2021-07-01    48776.745372
# 2021-08-01    48072.352311
# 2021-09-01    44831.449455
# 2021-10-01    60972.925629
# 2021-11-01    41000.447464
# 2021-12-01    56878.744723

# %%
mod =SARIMAX(em_series_year,
                                order=(0, 0, 1),
                                seasonal_order=(1, 0, 1, 2),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])

# mod =SARIMAX(em_series_year,
#                                 order=(1, 0, 0),
#                                 seasonal_order=(0, 0, 1, 12),
#                                 enforce_stationarity=False,
#                                 enforce_invertibility=False)

# results = mod.fit()

# print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.1527    399.252     -0.003      0.998    -783.673     781.368
# ar.S.L2        1.3347    494.765      0.003      0.998    -968.387     971.056
# ma.S.L2        0.8265    236.206      0.003      0.997    -462.129     463.782
# sigma2      7.268e+10   2.08e-07    3.5e+17      0.000    7.27e+10    7.27e+10
# ==============================================================================
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'

# %%
pred = results.get_prediction(start='2015-01-01', dynamic=False)
pred_ci = pred.conf_int()

ax = em_series_year['2011-01':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='forecast', alpha=.7, figsize=(14, 7),color='red')

# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Year')
ax.set_ylabel('revenue')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = em_series_year['2015-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted,)
# mape = mean_absolute_percentage_error(y_forecasted,y_truth)

print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# RMSE: 69841.951
# MAPE: 0.318

# %%
index = pd.to_datetime(['2019','2020','2021','2022','2023'])
pred_uc = results.get_forecast(steps=len(index),index=index)
pred_ci = pred_uc.conf_int()
ax = em_series_year.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='forecast',color='red')
# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Year')
ax.set_ylabel('revenue')
plt.legend()
plt.show()

# %%
pred_uc.predicted_mean.to_frame()
# Out:
#             predicted_mean
# 2019-01-01    62398.366133
# 2020-01-01   594882.850837
# 2021-01-01    82944.292523
# 2022-01-01   793969.924582
# 2023-01-01   110702.928461

# %%
df_1nz  = df_copy[df_copy["extracted_engine"].apply(lambda x : 'EJ25' in x)]
df_1nz
# Out:
#         index Register Date     HS Code  \
# 40138      27    2011-01-12  8407343009
# 40141     974    2011-01-18  8407343009
# 40145    1687    2011-02-09  8407343009
# 40158    2827    2011-03-28  8407343009
# 40163    2872    2011-03-11  8407343009
# ...       ...           ...         ...
# 43833  257271    2019-12-01  8407343009
# 43834  257287    2019-12-01  8407343009
# 43844  257477    2019-12-01  8407343009
# 43871  258428    2019-12-01  8407343009
# 43872  258429    2019-12-01  8407343009
#
#                                      Product Description  \
# 40138  БЕНЗИНОВЫЕ ДВИГАТЕЛИ ДЛЯ А/М, РАБОЧИМ ОБЪЕМОМ ...
# 40141  ДВИГАТЕЛИ БЕНЗИН.-21ШТ.,БЫВ.В УПОТРЕБЛ.ДЛЯ ЛЕК...
# 40145  ДВИГАТЕЛЬ ВНУТР. СГОРАНИЯ ДЛЯ Л/АВТОМОБИЛЯ, БЕ...
# 40158  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ Б/У ОТ А/М В СБОРЕ С АКП:...
# 40163  ДВИГ.БЕНЗ.БЫВ.В УП.ЛЕГК.А/М МАС.МЕНЕЕ 3.5Т.С К...
# ...                                                  ...
# 43833  ДВИГАТЕЛИ БЕНЗИНОВЫЕ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43834  ДВИГАТЕЛИ БЕНЗИНОВЫЕ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫ...
# 43844  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ Б/У ОТ А/М БЕЗ АКП, T.M.S...
# 43871  ЗАП.ЧАСТИ ДЛЯ АВТОМОБИЛЕЙ, Б/У: ДВИГАТЕЛИ БЫВШ...
# 43872  ЗАП.ЧАСТИ ДЛЯ АВТОМОБИЛЕЙ, Б/У: ДВИГАТЕЛИ БЫВШ...
#
#                                                 Producer  \
# 40138  DAIHATSU, HONDA, SUBARU, MAZDA, MITSUBISHI, NI...
# 40141  HONDA MOTOR COMPANY,TOYOTA MOTOR CORPORATION,S...
# 40145                             FUJI HEAVY CO., SUBARU
# 40158                                             SUBARU
# 40163  TOYOTA MOTOR CORPORATION,HONDA MOTOR CO.,LTD,N...
# ...                                                  ...
# 43833                                 SUBARU CORPORATION
# 43834                                 SUBARU CORPORATION
# 43844                                             SUBARU
# 43871                                             SUBARU
# 43872                                             SUBARU
#
#                                                    Brand Place of Receipt  \
# 40138  DAIHATSU, HONDA, SUBARU, MAZDA, MITSUBISHI, NI...      ВЛАДИВОСТОК
# 40141        HONDA,TOYOTA,SUBARU,MITSUBISHI,NISSAN,MAZDA        ВОСТОЧНЫЙ
# 40145                                             SUBARU     П-КАМЧАТСКИЙ
# 40158                                             SUBARU      ВЛАДИВОСТОК
# 40163        TOYOTA,NISSAN,HONDA,MAZDA,SUBARU,MITSUBISHI        ВОСТОЧНЫЙ
# ...                                                  ...              ...
# 43833                                             SUBARU      ВЛАДИВОСТОК
# 43834                                             SUBARU      ВЛАДИВОСТОК
# 43844                                             SUBARU      ВЛАДИВОСТОК
# 43871                                             SUBARU      ВЛАДИВОСТОК
# 43872                                             SUBARU      ВЛАДИВОСТОК
#
#       Country of Origin Country of Sales  \
# 40138    JP, JPN, Japan   JP, JPN, Japan
# 40141    JP, JPN, Japan   JP, JPN, Japan
# 40145    JP, JPN, Japan     CT, , Taiwan
# 40158    JP, JPN, Japan   JP, JPN, Japan
# 40163    JP, JPN, Japan   JP, JPN, Japan
# ...                 ...              ...
# 43833    JP, JPN, Japan   KR, KOR, Korea
# 43834    JP, JPN, Japan   KR, KOR, Korea
# 43844    JP, JPN, Japan   JP, JPN, Japan
# 43871    JP, JPN, Japan   JP, JPN, Japan
# 43872    JP, JPN, Japan   JP, JPN, Japan
#
#                                                 Shipper   ... Incoterms  \
# 40138                              KAIHO SANGYO CO., LTD  ...       CFR
# 40141  YAMADA MOTOR CO.,LTD.16-6,SHIMIZU-KU NISHITAKA...  ...       CFR
# 40145                                  DRUZHBA CO., LTD.  ...       CFR
# 40158                                     JAPROS CO,.LTD  ...       CFR
# 40163                               IMPEX JAPAN CO.,LTD.  ...       CFR
# ...                                                  ...  ...       ...
# 43833                                     MIRAGE CO. LTD  ...       CFR
# 43834                                     MIRAGE CO. LTD  ...       CFR
# 43844                AL KAMEEL AUTO USED SPARE PARTS TR.  ...       CFR
# 43871                                      ROOTS CO. LTD  ...       CFR
# 43872                                      ROOTS CO. LTD  ...       CFR
#
#       Gross Weight in KG Net Weight in KG  Cargo Value USD  \
# 40138            5010.00          5010.00          3263.98
# 40141            4594.00          4594.00          6891.00
# 40145             231.66           231.66           320.76
# 40158            1950.00          1950.00          1330.00
# 40163            6480.00          6480.00          3240.00
# ...                  ...              ...              ...
# 43833             230.00           230.00           347.30
# 43834             230.00           230.00           347.30
# 43844            1231.00          1231.00          1846.50
# 43871             340.00           340.00           512.20
# 43872             340.00           340.00           512.20
#
#                                  extracted_engine   brand  month_year  year  \
# 40138                                      [EJ25]  SUBARU     2011-01  2011
# 40141                                      [EJ25]  SUBARU     2011-01  2011
# 40145                                      [EJ25]  SUBARU     2011-02  2011
# 40158                                [EJ25, EJ25]  SUBARU     2011-03  2011
# 40163                          [EJ25, EJ15, EJ20]  SUBARU     2011-03  2011
# ...                                           ...     ...         ...   ...
# 43833                                      [EJ25]  SUBARU     2019-12  2019
# 43834                                      [EJ25]  SUBARU     2019-12  2019
# 43844  [EJ25, EJ25, EJ20, EJ20, EJ20, EJ20, FB20]  SUBARU     2019-12  2019
# 43871                                      [EJ25]  SUBARU     2019-12  2019
# 43872                                      [EJ25]  SUBARU     2019-12  2019
#
#        len_unique_em len_em
# 40138              1      1
# 40141              1      1
# 40145              1      1
# 40158              1      2
# 40163              3      3
# ...              ...    ...
# 43833              1      1
# 43834              1      1
# 43844              3      7
# 43871              1      1
# 43872              1      1
#
# [728 rows x 25 columns]

# %%
df_1nz['count_em']  = df_1nz['extracted_engine'].map(lambda x: count_length(x,'EJ25'))
unit_price_1nz = df_1nz[(df_1nz.Quantity == 1) & (df_1nz.count_em==1)].describe().loc[('mean','Cargo Value USD')]
df_1nz['Quantity'] = df_1nz.apply(lambda x : normalize_zero (x,unit_price_1nz), axis=1)
df_1nz['total_price'] = df_1nz.apply(lambda x : check_count_em(x,unit_price_1nz),axis=1)
# Out:
# <ipython-input-75-d83f80233319>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1nz['count_em']  = df_1nz['extracted_engine'].map(lambda x: count_length(x,'EJ25'))
# <ipython-input-75-d83f80233319>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1nz['Quantity'] = df_1nz.apply(lambda x : normalize_zero (x,unit_price_1nz), axis=1)
# <ipython-input-75-d83f80233319>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1nz['total_price'] = df_1nz.apply(lambda x : check_count_em(x,unit_price_1nz),axis=1)

# %%
df_1g  = df_copy[df_copy["extracted_engine"].apply(lambda x : '4G64' in x)]
df_1g
# Out:
#         index Register Date     HS Code  \
# 24135    1239    2011-02-01  8407343009
# 24143    1681    2011-02-09  8407343009
# 24160    2691    2011-02-28  8407343009
# 24176    2885    2011-03-14  8407343009
# 24177    2890    2011-03-14  8407343009
# ...       ...           ...         ...
# 30243  257586    2019-12-01  8407343009
# 30244  257683    2019-12-01  8407343009
# 30251  257880    2019-12-01  8407343009
# 30255  257959    2019-12-01  8407343009
# 30262  258291    2019-12-01  8407343009
#
#                                      Product Description  \
# 24135  ДВИГАТЕЛЬ А/М Б/У БЕНЗИН С ОБЪЕМОМ БОЛЕЕ 1000С...
# 24143  ДВИГАТЕЛЬ ВНУТР. СГОРАНИЯ ДЛЯ Л/АВТОМОБИЛЯ, С ...
# 24160  ДВИГАТЕЛИ БЕНЗ.БЫВ.В УП.В СБОРЕ С НАВЕСНЫМ ОБО...
# 24176  ДВИГАТЕЛИ ВНУТРЕННЕГО СГОРАНИЯ БЫВШИЕ В УПОТРЕ...
# 24177  ДВИГАТЕЛИ ВНУТРЕННЕГО СГОРАНИЯ БЫВШИЕ В УПОТРЕ...
# ...                                                  ...
# 30243  ДВИГАТЕЛИ БЕНЗИНОВЫЕ БЫВШИЕ В УПОТРЕБЛЕНИИ СТА...
# 30244  ЗАП.ЧАСТИ ДЛЯ АВТОМОБИЛЕЙ, Б/У: ДВИГАТЕЛИ БЫВШ...
# 30251  ЗАПАСНЫЕ ЧАСТИ ДЛЯ А/М, Б/У, ДВИГАТЕЛИ ВНУТРЕН...
# 30255  ЗАП.ЧАСТИ ДЛЯ АВТОМОБИЛЕЙ, Б/У: ДВИГАТЕЛИ БЫВШ...
# 30262  ДВИГАТЕЛИ БЕНЗИНОВЫЕ В СБОРЕ С КОРОБКОЙ ПЕРЕДА...
#
#                                                 Producer  \
# 24135                      MITSUBISHI,TOYOTA,MAZDA,HONDA
# 24143                   MITSUBISHI MOTOR CO., MITSUBISHI
# 24160  TOYOTA MOTOR CORPORATION,HONDA MOTOR CO.,LTD,N...
# 24176  HONDA MOTOR CO.,LTD,MITSUBISHI MOTORS CORPORAT...
# 24177  HONDA MOTOR CO.,LTD,MITSUBISHI MOTORS CORPORAT...
# ...                                                  ...
# 30243                                MITSUBISHI MOTOR CO
# 30244                                         MITSUBISHI
# 30251                                         MITSUBISHI
# 30255                                         MITSUBISHI
# 30262                         DAIHATSU MITSUBISHI SUZUKI
#
#                                 Brand Place of Receipt Country of Origin  \
# 24135   MITSUBISHI,TOYOTA,MAZDA,HONDA      ВЛАДИВОСТОК    JP, JPN, Japan
# 24143                      MITSUBISHI     П-КАМЧАТСКИЙ    JP, JPN, Japan
# 24160  TOYOTA,HONDA,NISSAN,SUZUKI,MMC        ВОСТОЧНЫЙ    JP, JPN, Japan
# 24176   HONDA,MITSUBISHI,MAZDA,SUBARU    CFR ВОСТОЧНЫЙ    JP, JPN, Japan
# 24177   HONDA,MITSUBISHI,MAZDA,SUBARU    CFR ВОСТОЧНЫЙ    JP, JPN, Japan
# ...                               ...              ...               ...
# 30243                      MITSUBISHI        ВОСТОЧНЫЙ    JP, JPN, Japan
# 30244                      MITSUBISHI      ВЛАДИВОСТОК    JP, JPN, Japan
# 30251                      MITSUBISHI      ВЛАДИВОСТОК    JP, JPN, Japan
# 30255                      MITSUBISHI      ВЛАДИВОСТОК    JP, JPN, Japan
# 30262      DAIHATSU MITSUBISHI SUZUKI      ВЛАДИВОСТОК    JP, JPN, Japan
#
#       Country of Sales                                           Shipper   \
# 24135     CT, , Taiwan                               PIONEER COMPANY LTD.
# 24143     CT, , Taiwan                                  DRUZHBA CO., LTD.
# 24160     CT, , Taiwan                                   JEEP SIB CO.,LTD
# 24176   JP, JPN, Japan  ROYAL AUTO PARTS CO.,LTD 724-141 OKIHARU BESHI...
# 24177   JP, JPN, Japan  HEIWA SYOUJI KABUSHIKIGAISHA 10-8 MINAMIFUTAJI...
# ...                ...                                                ...
# 30243   JP, JPN, Japan                             KUSAYAMA PARTS CO. LTD
# 30244   JP, JPN, Japan                                IWAMA WORKS CO. LTD
# 30251   JP, JPN, Japan                              MARUKO SHOJI CO. LTD.
# 30255   JP, JPN, Japan                                   KAWASHIMA CO.LTD
# 30262   JP, JPN, Japan                       LUXMAN ENTERPRISE JAPAN LTD.
#
#        ... Incoterms Gross Weight in KG Net Weight in KG  Cargo Value USD  \
# 24135  ...       CFR             5730.0           5730.0          3617.32
# 24143  ...       CFR              613.8            613.8           693.00
# 24160  ...       CFR             6970.0           6970.0          3400.00
# 24176  ...       CFR             9029.4           9029.4          8934.67
# 24177  ...       CFR             7068.6           7068.6          6962.42
# ...    ...       ...                ...              ...              ...
# 30243  ...       CFR             2450.0           2450.0          3765.79
# 30244  ...       CFR              260.0            260.0           393.06
# 30251  ...       CFR              960.0            960.0          1449.60
# 30255  ...       CFR              240.0            240.0           361.99
# 30262  ...       CFR              930.0            930.0          1413.60
#
#                      extracted_engine       brand  month_year  year  \
# 24135                    [4G93, 4G64]  MITSUBISHI     2011-02  2011
# 24143                    [4G64, 4G63]  MITSUBISHI     2011-02  2011
# 24160                    [4G64, 4G63]  MITSUBISHI     2011-02  2011
# 24176  [4G15, 4G64, 4G64, 4G64, 4G63]  MITSUBISHI     2011-03  2011
# 24177                    [4G13, 4G64]  MITSUBISHI     2011-03  2011
# ...                               ...         ...         ...   ...
# 30243                    [4G15, 4G64]  MITSUBISHI     2019-12  2019
# 30244                          [4G64]  MITSUBISHI     2019-12  2019
# 30251                    [4G93, 4G64]  MITSUBISHI     2019-12  2019
# 30255                          [4G64]  MITSUBISHI     2019-12  2019
# 30262                          [4G64]  MITSUBISHI     2019-12  2019
#
#        len_unique_em len_em
# 24135              2      2
# 24143              2      2
# 24160              2      2
# 24176              3      5
# 24177              2      2
# ...              ...    ...
# 30243              2      2
# 30244              1      1
# 30251              2      2
# 30255              1      1
# 30262              1      1
#
# [984 rows x 25 columns]

# %%
df_1g['count_em']  = df_1g['extracted_engine'].map(lambda x: count_length(x,'D15B'))
unit_price_1g = df_1g[(df_1g.Quantity == 1) & (df_1g.count_em==1)].describe().loc[('mean','Cargo Value USD')]
df_1g['Quantity'] = df_1g.apply(lambda x : normalize_zero (x,unit_price_1g), axis=1)
df_1g['total_price'] = df_1g.apply(lambda x : check_count_em(x,unit_price_1g),axis=1)
# Out:
# <ipython-input-123-bc9c92a6926c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1g['count_em']  = df_1g['extracted_engine'].map(lambda x: count_length(x,'D15B'))
# <ipython-input-3-8b73a2289c4c>:16: RuntimeWarning: invalid value encountered in double_scalars
#   if row['Cargo Value USD'] % unit_price < 2:
# <ipython-input-3-8b73a2289c4c>:19: RuntimeWarning: invalid value encountered in double_scalars
#   return row['Cargo Value USD'] // unit_price
# <ipython-input-123-bc9c92a6926c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1g['Quantity'] = df_1g.apply(lambda x : normalize_zero (x,unit_price_1g), axis=1)
# <ipython-input-123-bc9c92a6926c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1g['total_price'] = df_1g.apply(lambda x : check_count_em(x,unit_price_1g),axis=1)

# %%
df_fp  = df_copy[df_copy["extracted_engine"].apply(lambda x : 'L13A' in x)]
df_fp
# Out:
#         index Register Date     HS Code  \
# 24127      91    2011-01-21  8407343009
# 24131     974    2011-01-18  8407343009
# 24144    1698    2011-02-08  8407343009
# 24155    2636    2011-02-24  8407343009
# 24161    2695    2011-02-28  8407343009
# ...       ...           ...         ...
# 30259  258189    2019-12-01  8407343009
# 30264  258373    2019-12-01  8407343009
# 30266  258418    2019-12-01  8407343009
# 30267  258419    2019-12-01  8407343009
# 30268  258420    2019-12-01  8407343009
#
#                                      Product Description  \
# 24127  ЗАП.ЧАСТИ ДЛЯ А/М, Б/У ДВИГАТЕЛЯ С АКП ЯПОНСКО...
# 24131  ДВИГАТЕЛИ БЕНЗИН.-21ШТ.,БЫВ.В УПОТРЕБЛ.ДЛЯ ЛЕК...
# 24144  ДВИГАТЕЛЬ БЕНЗИНОВЫЙ Б/У ОТ А/М В СБОРЕ С АКП:...
# 24155  ДВИГАТЕЛИ БЕНЗИНОВЫЕ С ОБЪЁМОМ БОЛЕЕ 1000СМ3, ...
# 24161  ДВИГАТЕЛИ ВНУТРЕННЕГО СГОРАНИЯ БЫВШИЕ В УПОТРЕ...
# ...                                                  ...
# 30259  ДВИГАТЕЛИ ВНУТРЕННЕГО СГОРАНИЯ БЫВШИЕ В УПОТРЕ...
# 30264  ДВИГАТЕЛЬ АВТОМОБИЛЬНЫЙ БЫВШИЙ В УПОТРЕБЛЕНИИ,...
# 30266  ЗАП.ЧАСТИ ДЛЯ АВТОМОБИЛЕЙ, Б/У: ДВИГАТЕЛИ БЫВШ...
# 30267  ЗАП.ЧАСТИ ДЛЯ АВТОМОБИЛЕЙ, Б/У: ДВИГАТЕЛИ БЫВШ...
# 30268  ЗАП.ЧАСТИ ДЛЯ АВТОМОБИЛЕЙ, Б/У: ДВИГАТЕЛИ БЫВШ...
#
#                                                 Producer  \
# 24127                           TOYOTA,MITSUBISHI,SUBARU
# 24131  HONDA MOTOR COMPANY,TOYOTA MOTOR CORPORATION,S...
# 24144                                         MITSUBISHI
# 24155                  HONDA, TOYOTA, MITSUBISHI, NISSAN
# 24161          MITSUBISHI MOTORS CORPORATION, MITSUBISHI
# ...                                                  ...
# 30259  FUJI HEAVY INDUSTRIES CO.LTDMITSUBISHI MOTORS ...
# 30264                      MITSUBISHI MOTORS CORPORATION
# 30266                                         MITSUBISHI
# 30267                                         MITSUBISHI
# 30268                                         MITSUBISHI
#
#                                              Brand Place of Receipt  \
# 24127                     TOYOTA,MITSUBISHI,SUBARU      ВЛАДИВОСТОК
# 24131  HONDA,TOYOTA,SUBARU,MITSUBISHI,NISSAN,MAZDA        ВОСТОЧНЫЙ
# 24144                                   MITSUBISHI      ВЛАДИВОСТОК
# 24155                                        HONDA      ВЛАДИВОСТОК
# 24161                                   MITSUBISHI    CFR ВОСТОЧНЫЙ
# ...                                            ...              ...
# 30259                             SUBARUMITSUBISHI        ВОСТОЧНЫЙ
# 30264                                   MITSUBISHI      ВЛАДИВОСТОК
# 30266                                   MITSUBISHI      ВЛАДИВОСТОК
# 30267                                   MITSUBISHI      ВЛАДИВОСТОК
# 30268                                   MITSUBISHI      ВЛАДИВОСТОК
#
#       Country of Origin    Country of Sales  \
# 24127    JP, JPN, Japan      JP, JPN, Japan
# 24131    JP, JPN, Japan      JP, JPN, Japan
# 24144    JP, JPN, Japan        CT, , Taiwan
# 24155    JP, JPN, Japan        CT, , Taiwan
# 24161    JP, JPN, Japan        CT, , Taiwan
# ...                 ...                 ...
# 30259    JP, JPN, Japan      JP, JPN, Japan
# 30264    JP, JPN, Japan  HK, HKG, Hong Kong
# 30266    JP, JPN, Japan      JP, JPN, Japan
# 30267    JP, JPN, Japan      JP, JPN, Japan
# 30268    JP, JPN, Japan      JP, JPN, Japan
#
#                                                 Shipper   ... Incoterms  \
# 24127                             АВТОЛОМ ДЖАПАН КО.,ЛТД  ...       CFR
# 24131  YAMADA MOTOR CO.,LTD.16-6,SHIMIZU-KU NISHITAKA...  ...       CFR
# 24144                               WAKE CORPORATION LTD  ...       CFR
# 24155  FESCO LINES VLADIVOSTOK,LLC, 34POSYETSKAYA STR...  ...       CFR
# 24161  ROYAL AUTO PARTS CO.,LTD 724-141 OKIHARU BESHI...  ...   unknown
# ...                                                  ...  ...       ...
# 30259              WEST-JAPAN AUTO RECYCLE CO.LTD (WARC)  ...       CFR
# 30264                        TRUTH LOGISTICS CORPORATION  ...       CFR
# 30266                                      ROOTS CO. LTD  ...       CFR
# 30267                                      ROOTS CO. LTD  ...       CFR
# 30268                                      ROOTS CO. LTD  ...       CFR
#
#       Gross Weight in KG Net Weight in KG  Cargo Value USD  \
# 24127              600.0            600.0           480.00
# 24131             4594.0           4594.0          6891.00
# 24144             2079.0           2079.0           752.40
# 24155             2280.0           2280.0          1080.00
# 24161             7480.0           7480.0          7534.52
# ...                  ...              ...              ...
# 30259             1229.0           1229.0          1866.49
# 30264              570.0            570.0           855.06
# 30266              210.0            210.0           316.36
# 30267              210.0            210.0           316.36
# 30268              210.0            210.0           316.36
#
#                      extracted_engine       brand  month_year  year  \
# 24127                          [4G15]  MITSUBISHI     2011-01  2011
# 24131                    [6G74, 4G15]  MITSUBISHI     2011-01  2011
# 24144        [4G13, 4G15, 6A13, 6A13]  MITSUBISHI     2011-02  2011
# 24155                          [4G15]  MITSUBISHI     2011-02  2011
# 24161  [4G15, 4G15, 4G15, 4G15, 4G15]  MITSUBISHI     2011-02  2011
# ...                               ...         ...         ...   ...
# 30259              [6G74, 4G15, 4B11]  MITSUBISHI     2019-12  2019
# 30264              [4G15, 4A91, 4A91]  MITSUBISHI     2019-12  2019
# 30266                          [4G15]  MITSUBISHI     2019-12  2019
# 30267                          [4G15]  MITSUBISHI     2019-12  2019
# 30268                          [4G15]  MITSUBISHI     2019-12  2019
#
#        len_unique_em len_em
# 24127              1      1
# 24131              2      2
# 24144              3      4
# 24155              1      1
# 24161              1      5
# ...              ...    ...
# 30259              3      3
# 30264              2      3
# 30266              1      1
# 30267              1      1
# 30268              1      1
#
# [1165 rows x 25 columns]

# %%
df_fp['count_em']  = df_fp['extracted_engine'].map(lambda x: count_length(x,'L13A'))
unit_price_1g = df_fp[(df_fp.Quantity == 1) & (df_fp.count_em==1)].describe().loc[('mean','Cargo Value USD')]
df_fp['Quantity'] = df_fp.apply(lambda x : normalize_zero (x,unit_price_1g), axis=1)
df_fp['total_price'] = df_fp.apply(lambda x : check_count_em(x,unit_price_1g),axis=1)
# Out:
# <ipython-input-125-b245907ec55e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fp['count_em']  = df_fp['extracted_engine'].map(lambda x: count_length(x,'L13A'))
# <ipython-input-3-8b73a2289c4c>:16: RuntimeWarning: invalid value encountered in double_scalars
#   if row['Cargo Value USD'] % unit_price < 2:
# <ipython-input-3-8b73a2289c4c>:19: RuntimeWarning: invalid value encountered in double_scalars
#   return row['Cargo Value USD'] // unit_price
# <ipython-input-125-b245907ec55e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fp['Quantity'] = df_fp.apply(lambda x : normalize_zero (x,unit_price_1g), axis=1)
# <ipython-input-125-b245907ec55e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fp['total_price'] = df_fp.apply(lambda x : check_count_em(x,unit_price_1g),axis=1)

# %%
df_3s['name_em'] = 'EJ20'
df_1nz['name_em'] = 'EJ25'
# df_1g['name_em'] = 'D15B'
# df_fp['name_em'] = 'L13A'
# Out:
# <ipython-input-76-2552e5839309>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3s['name_em'] = 'EJ20'
# <ipython-input-76-2552e5839309>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1nz['name_em'] = 'EJ25'

# %%
df_best_engine  = pd.concat([df_3s,df_1nz],axis=0)

# %%
df_group_year = df_best_engine.groupby(['year','name_em'])['total_price'].sum().reset_index()
df_group_year
# Out:
#     year name_em    total_price
# 0   2011    EJ20  155024.148287
# 1   2011    EJ25   18788.698571
# 2   2012    EJ20  201477.743068
# 3   2012    EJ25   21659.654286
# 4   2013    EJ20  324477.864143
# 5   2013    EJ25   47151.572857
# 6   2014    EJ20  355049.714821
# 7   2014    EJ25   39265.417143
# 8   2015    EJ20  245029.354582
# 9   2015    EJ25   45079.452857
# 10  2016    EJ20  182043.187968
# 11  2016    EJ25   43388.534286
# 12  2017    EJ20  260713.520199
# 13  2017    EJ25   75428.804286
# 14  2018    EJ20   50735.097171
# 15  2018    EJ25   10902.161429
# 16  2019    EJ20  461872.276096
# 17  2019    EJ25  110536.138571

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='year',y='total_price',hue='name_em',data=df_group_year)
plt.ylabel('revenue')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
df_group_month = df_best_engine.groupby(['month_year','name_em'])['total_price'].sum().reset_index()
df_group_month
# Out:
#     month_year name_em   total_price
# 0      2011-01    EJ20   3490.054821
# 1      2011-01    EJ25  10154.980000
# 2      2011-02    EJ20   7570.801116
# 3      2011-02    EJ25    320.760000
# 4      2011-03    EJ20  24262.428924
# ..         ...     ...           ...
# 169    2019-10    EJ25   8398.478571
# 170    2019-11    EJ20  38584.220438
# 171    2019-11    EJ25   9055.814286
# 172    2019-12    EJ20  36317.931155
# 173    2019-12    EJ25  12977.368571
#
# [174 rows x 3 columns]

# %%
plt.figure(figsize=(20,8))
sns.lineplot(x='month_year',y='total_price',hue='name_em',data=df_group_month)
plt.xticks(rotation = 90)
plt.ylabel('revenue')
plt.xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %%
plt.figure(figsize=(25,14))
sns.boxplot(x='month_year',y='total_price',data=df_3s)
# plt.xticks(rotation = 90)
plt.xticks(fontsize = 15,rotation = 90, weight='bold')
plt.yticks(fontsize = 15)
plt.ylabel('revenue',fontsize = 15)
plt.xlabel('Month',fontsize = 15)
# Out:
# Text(0.5, 0, 'Month')

# %%
plt.figure(figsize=(20,15))
sns.boxplot(x='year',y='total_price',data=df_3s)
# plt.xticks(rotation = 90)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.ylabel('revenue',fontsize = 20)
plt.xlabel('Year',fontsize = 20)
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # Engine Model EJ25

# %%
df_sum_day = df_1nz.groupby(['Register Date'])['total_price'].sum().reset_index()
df_sum_month = df_1nz.groupby(['month_year'])['total_price'].sum().reset_index()
df_sum_year = df_1nz.groupby(['year'])['total_price'].sum().reset_index()
df_sum_month['month_year'] = pd.to_datetime(df_sum_month['month_year'],format='%Y-%m')
df_sum_month.set_index('month_year',inplace = True)
# df_sum_day['Register Date'] = df_sum_day['Register Date'].astype(str)
df_sum_year['year'] = pd.to_datetime(df_sum_year['year'],format='%Y')
em_series_month =  pd.Series(df_sum_month.total_price.values,index=df_sum_month.index)
em_series_year =  pd.Series(df_sum_year.total_price.values,index=df_sum_year['year'])
em_series = pd.Series(df_sum_day.total_price.values,index=df_sum_day['Register Date'])
em_series_sample = pd.Series(df_1nz.total_price.values,index=df_1nz['Register Date'])

# %%
plt.figure(figsize=(25,14))
sns.boxplot(x='month_year',y='total_price',data=df_1nz)
# plt.xticks(rotation = 90)
plt.xticks(fontsize = 15,rotation = 90, weight='bold')
plt.yticks(fontsize = 15)
plt.ylabel('revenue',fontsize = 15)
plt.xlabel('Month',fontsize = 15)
# Out:
# Text(0.5, 0, 'Month')

# %%
plt.figure(figsize=(20,15))
sns.boxplot(x='year',y='total_price',data=df_1nz)
# plt.xticks(rotation = 90)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.ylabel('revenue',fontsize = 20)
plt.xlabel('Year',fontsize = 20)
# Out:
# Text(0.5, 0, 'Year')

# %%
X = np.log(em_series_month).values
size = int(len(X) * 0.70)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# model = ARIMA(np.log(em_series_month), order=(5,1,0))
# results = model.fit()
# pred = results.predict(start='2017-01', dynamic=False)
# y_forecasted = np.exp(pred)
# y_truth = em_series_month['2017-01-01':]
# rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
# mape = mean_absolute_percentage_error(y_truth, y_forecasted)
# print('RMSE: %.3f' % rmse)
# print('MAPE: %.3f' % mape)
# # plot forecasts against actual outcomes
# plt.xticks(rotation = 90)
# plt.plot(y_forecasted,color='red')
# plt.plot(em_series_month)
# plt.show()
#walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,1))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))
# evaluate forecasts
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)
rmse = mean_squared_error(np.exp(test), np.exp(predictions),squared=False)
mape = mean_absolute_percentage_error(np.exp(test), np.exp(predictions))
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=5348.357871, expected=840.931429
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=4975.980599, expected=2313.468571
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=3218.155590, expected=8184.448571
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=5390.149724, expected=1277.328571
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=3681.837257, expected=6888.510000
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=4408.386497, expected=2176.397143
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=4665.506120, expected=14753.600000
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=4817.972421, expected=14775.242857
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=5982.675639, expected=1532.794286
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=5983.228821, expected=7488.654286
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=5106.994160, expected=19334.038571
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=6489.179501, expected=11996.817143
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=7235.144589, expected=3371.260000
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=6414.254709, expected=10902.161429
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=7482.266573, expected=9621.040000
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=7803.207169, expected=6427.860000
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=7610.239741, expected=6148.234286
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=7631.265401, expected=15214.972857
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=8279.577020, expected=5301.681429
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=8211.381177, expected=7299.195714
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=8417.934725, expected=15418.391429
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=8860.177222, expected=11604.665714
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=9158.108945, expected=3068.435714
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=9191.874185, expected=8398.478571
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# predicted=9690.412096, expected=9055.814286
# predicted=9328.562651, expected=12977.368571
# RMSE: 5402.396
# MAPE: 0.924
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
decomposition = seasonal_decompose(em_series_month, model='additive',period = 2)
plt.figure(figsize=(12,8))
plt.xticks(fontsize = 20, rotation = 0)
plt.yticks(fontsize = 20, rotation = 0)
plt.xlabel('Year',fontsize = 20)
plt.ylabel('value',fontsize = 20)
plt.plot(decomposition.trend)

# %%
df_sum_month.reset_index(inplace=True)
df_sum_month['month_year'] = df_sum_month['month_year'].astype(str)
list_datetime = list(df_sum_month['month_year'][size:len(X)])
plt.figure(figsize=(12,8))
plt.plot(np.exp(predictions), color='red')
plt.xticks(rotation = 90)
plt.xlabel('Month')
plt.ylabel('revenue')
sns.lineplot(x=list_datetime,y='total_price',data=df_sum_month[size:len(X)])
plt.legend(loc='upper left', labels=['forecast','test'])

# %%
X = np.log(em_series_year).values
size = int(len(X) * 0.75)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# model = ARIMA(np.log(em_series_month), order=(5,1,0))
# results = model.fit()
# pred = results.predict(start='2017-01', dynamic=False)
# y_forecasted = np.exp(pred)
# y_truth = em_series_month['2017-01-01':]
# rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
# mape = mean_absolute_percentage_error(y_truth, y_forecasted)
# print('RMSE: %.3f' % rmse)
# print('MAPE: %.3f' % mape)
# # plot forecasts against actual outcomes
# plt.xticks(rotation = 90)
# plt.plot(y_forecasted,color='red')
# plt.plot(em_series_month)
# plt.show()
#walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(1,0,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))
# evaluate forecasts
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)
rmse = mean_squared_error(np.exp(test), np.exp(predictions),squared=False)
mape = mean_absolute_percentage_error(np.exp(test), np.exp(predictions))
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# predicted=37532.875846, expected=75428.804286
# predicted=57874.673145, expected=10902.161429
# predicted=47928.162520, expected=110536.138571
# RMSE: 50207.161
# MAPE: 1.792
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
import math
min_aic = math.inf
list_param = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
            mod = SARIMAX(em_series_year,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            if results.aic < min_aic:
                min_aic  = results.aic
                list_param.clear()
                list_param.append(param)
                list_param.append(param_seasonal)
print(min_aic,list_param)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-928dcd2d2db1> in <module>
#       2 min_aic = math.inf
#       3 list_param = []
# ----> 4 for param in pdq:
#       5     for param_seasonal in seasonal_pdq:
#       6             mod = SARIMAX(em_series_year,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
#
# NameError: name 'pdq' is not defined

# %%
mod =SARIMAX(em_series_month,
#                                 order=(5, 0, 0),
#                                 seasonal_order=(5, 0, 0, 12),
                                order=(5, 0, 1),
                                seasonal_order=(5, 0, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7881      0.242      3.254      0.001       0.313       1.263
# ar.L2         -0.3920      0.290     -1.352      0.176      -0.960       0.176
# ar.L3          0.2291      0.249      0.922      0.357      -0.258       0.716
# ar.L4          0.1607      0.262      0.613      0.540      -0.353       0.675
# ar.L5         -0.5305      0.244     -2.171      0.030      -1.009      -0.052
# ma.L1         -1.0081      0.417     -2.420      0.016      -1.825      -0.191
# ar.S.L12      -0.4977      0.700     -0.711      0.477      -1.870       0.875
# ar.S.L24       0.5505      0.503      1.095      0.274      -0.435       1.536
# ar.S.L36       0.6265      0.284      2.206      0.027       0.070       1.183
# ar.S.L48       1.4288      0.661      2.162      0.031       0.134       2.724
# ar.S.L60       1.0305      1.230      0.838      0.402      -1.380       3.442
# ma.S.L12       0.3677      0.735      0.501      0.617      -1.072       1.807
# sigma2      1.039e+07   4.07e-08   2.56e+14      0.000    1.04e+07    1.04e+07
# ==============================================================================
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-6cfeaa52b7c1> in <module>
# ----> 1 results.plot_diagnostics(figsize=(16, 8))
#       2 plt.show()
#
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in plot_diagnostics(self, variable, lags, fig, figsize, truncate_endog_names)
#    4282
#    4283         if resid.shape[0] < max(d, lags):
# -> 4284             raise ValueError(
#    4285                 "Length of endogenous variable must be larger the the number "
#    4286                 "of lags used in the model and the number of observations "
#
# ValueError: Length of endogenous variable must be larger the the number of lags used in the model and the number of observations burned in the log-likelihood calculation.

# %%
pred = results.get_prediction(start='2017-01', dynamic=False)
pred_ci = pred.conf_int()

ax = em_series_month['2017-01':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='forecast', color='red', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Month')
ax.set_ylabel('revenue')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = em_series_month['2017-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-41cea9e91bb5> in <module>
#       1 y_forecasted = pred.predicted_mean
#       2 y_truth = em_series_month['2017-01-01':]
# ----> 3 rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
#       4 mape = mean_absolute_percentage_error(y_truth, y_forecasted)
#       5 print('RMSE: %.3f' % rmse)
#
# D:\Software\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# D:\Software\Anaconda\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     333     0.825...
#     334     """
# --> 335     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     336         y_true, y_pred, multioutput)
#     337     check_consistent_length(y_true, y_pred, sample_weight)
#
# D:\Software\Anaconda\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      86         the dtype argument passed to check_array.
#      87     """
# ---> 88     check_consistent_length(y_true, y_pred)
#      89     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      90     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# D:\Software\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     260     uniques = np.unique(lengths)
#     261     if len(uniques) > 1:
# --> 262         raise ValueError("Found input variables with inconsistent numbers of"
#     263                          " samples: %r" % [int(l) for l in lengths])
#     264
#
# ValueError: Found input variables with inconsistent numbers of samples: [21, 6]

# %%
index = pd.to_datetime(['2020-01-01', '2020-02-01','2020-03-01','2020-02-01','2020-04-01','2020-05-01',
                        '2020-06-01','2020-07-01','2020-08-01','2020-09-01','2020-10-01','2020-11-01','2020-12-01',
                       '2021-01-01', '2021-02-01','2021-03-01','2021-02-01','2021-04-01','2021-05-01',
                        '2021-06-01','2021-07-01','2021-08-01','2021-09-01','2021-10-01','2021-11-01','2021-12-01'])
pred_uc = results.get_forecast(steps=len(index),index=index)
pred_ci = pred_uc.conf_int()
ax = em_series_month.plot(label='observed', figsize=(14, 7),)
pred_uc.predicted_mean.plot(ax=ax, label='forecast',color='red')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Month')
ax.set_ylabel('revenue')
plt.legend()
plt.show()

# %%
pred_uc.predicted_mean.to_frame()
# Out:
#             predicted_mean
# 2020-01-01    10488.980719
# 2020-02-01     7260.501859
# 2020-03-01    13234.726368
# 2020-02-01     9006.463048
# 2020-04-01    11874.304653
# 2020-05-01    15741.673792
# 2020-06-01    10020.100425
# 2020-07-01     9776.251032
# 2020-08-01    17773.029595
# 2020-09-01    13104.283067
# 2020-10-01    12742.861230
# 2020-11-01    10044.690181
# 2020-12-01    14494.243173
# 2021-01-01    13063.726998
# 2021-02-01     7805.557318
# 2021-03-01     9802.036577
# 2021-02-01    13150.406351
# 2021-04-01    15486.036860
# 2021-05-01    15292.653838
# 2021-06-01    14532.535935
# 2021-07-01    10975.888176
# 2021-08-01    24303.008977
# 2021-09-01    10892.955587
# 2021-10-01    13747.001705
# 2021-11-01    20668.544896
# 2021-12-01    10858.016929

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter for SARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter for SARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
import math
min_aic = math.inf
list_param = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
            mod = SARIMAX(em_series_year,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            if results.aic < min_aic:
                min_aic  = results.aic
                list_param.clear()
                list_param.append(param)
                list_param.append(param_seasonal)
print(min_aic,list_param)
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# D:\Software\Anaconda\lib\site-packages\numpy\core\_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# D:\Software\Anaconda\lib\site-packages\numpy\core\_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# 2.0 [(0, 0, 0), (0, 1, 0, 12)]
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'

# %%
mod =SARIMAX(em_series_year,
#                                 order=(1, 0, 0),
#                                 seasonal_order=(0, 1, 0, 2),
                                order=(0, 0, 0),
                                seasonal_order=(0, 1, 0, 2),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      4.827e+08   3.73e+08      1.293      0.196   -2.49e+08    1.21e+09
# ==============================================================================
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'

# %%
pred = results.get_prediction(start='2014-01-01', dynamic=False)
pred_ci = pred.conf_int()

ax = em_series_year['2014-01':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='forecast', color='red', alpha=.7, figsize=(14, 7))

# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Year')
ax.set_ylabel('revenue')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = em_series_year['2014-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted,)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# RMSE: 24290.702
# MAPE: 0.715

# %%
index = pd.to_datetime(['2019', '2020','2021','2022','2023','2024'])
pred_uc = results.get_forecast(steps=len(index),index=index)
pred_ci = pred_uc.conf_int()
ax = em_series_year.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='forecast',color='red')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Year')
ax.set_ylabel('revenue')
plt.legend()
plt.show()

# %%
pred_uc.predicted_mean.to_frame()
# Out:
#             predicted_mean
# 2019-01-01    10902.161429
# 2020-01-01   110536.138571
# 2021-01-01    10902.161429
# 2022-01-01   110536.138571
# 2023-01-01    10902.161429
# 2024-01-01   110536.138571

# %% [markdown]
# # Engine Model D15B

# %%
df_sum_day = df_1g.groupby(['Register Date'])['total_price'].sum().reset_index()
df_sum_month = df_1g.groupby(['month_year'])['total_price'].sum().reset_index()
df_sum_year = df_1g.groupby(['year'])['total_price'].sum().reset_index()
df_sum_month['month_year'] = pd.to_datetime(df_sum_month['month_year'],format='%Y-%m')
df_sum_month.set_index('month_year',inplace = True)
# df_sum_day['Register Date'] = df_sum_day['Register Date'].astype(str)
df_sum_year['year'] = pd.to_datetime(df_sum_year['year'],format='%Y')
em_series_month =  pd.Series(df_sum_month.total_price.values,index=df_sum_month.index)
em_series_year =  pd.Series(df_sum_year.total_price.values,index=df_sum_year['year'])
em_series = pd.Series(df_sum_day.total_price.values,index=df_sum_day['Register Date'])
em_series_sample = pd.Series(df_1g.total_price.values,index=df_1g['Register Date'])

# %%
len(train)
# Out:
# 65

# %%
decomposition = seasonal_decompose(em_series_month, model='additive',period = 2)
plt.figure(figsize=(12,8))
plt.xticks(fontsize = 20, rotation = 0)
plt.yticks(fontsize = 20, rotation = 0)
plt.xlabel('Year',fontsize = 20)
plt.ylabel('value',fontsize = 20)
plt.plot(decomposition.trend)

# %%
X = np.log(em_series_month).values
size = int(len(X) * 0.7)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,0,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))
# evaluate forecasts
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)
rmse = mean_squared_error(np.exp(test), np.exp(predictions),squared=False)
mape = mean_absolute_percentage_error(np.exp(test), np.exp(predictions))
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# predicted=8563.907002, expected=17784.000000
# predicted=12598.944140, expected=23826.150000
# predicted=14373.333012, expected=26631.280000
# predicted=21900.953163, expected=24247.160000
# predicted=19913.711848, expected=19864.550000
# predicted=21774.249038, expected=10312.190000
# predicted=20950.499374, expected=13706.370000
# predicted=16254.178418, expected=12758.300000
# predicted=15238.314845, expected=23736.850000
# predicted=13699.496898, expected=16121.070000
# predicted=17763.960543, expected=32307.130000
# predicted=16770.007810, expected=31277.850000
# predicted=21828.792673, expected=9490.730000
# predicted=22272.012157, expected=19383.310000
# predicted=18238.193422, expected=50400.250000
# predicted=16860.114263, expected=29262.740000
# predicted=19446.451409, expected=17836.900000
# predicted=24771.799494, expected=25864.310000
# predicted=23620.680138, expected=24677.910000
# predicted=20294.893826, expected=21095.590000
# predicted=19878.398722, expected=23982.990000
# predicted=21086.154573, expected=44120.850000
# predicted=20402.473149, expected=28386.680000
# predicted=23744.103728, expected=26730.130000
# predicted=24545.253558, expected=42641.680000
# predicted=25580.330694, expected=29613.440000
# predicted=25191.944900, expected=26374.290000
# RMSE: 11192.862
# MAPE: 0.344

# %%
df_sum_month.reset_index(inplace=True)
df_sum_month['month_year'] = df_sum_month['month_year'].astype(str)
list_datetime = list(df_sum_month['month_year'][40:len(X)])
plt.figure(figsize=(12,8))
plt.plot(np.exp(predictions), color='red')
plt.xticks(rotation = 90)
plt.xlabel('Month')
plt.ylabel('revenue')
sns.lineplot(x=list_datetime,y='total_price',data=df_sum_month[40:len(X)])
plt.legend(loc='upper left', labels=['forecast','test'])

# %%
import math
min_aic = math.inf
list_param = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
            mod = SARIMAX(em_series_month,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            if results.aic < min_aic:
                min_aic  = results.aic
                list_param.clear()
                list_param.append(param)
                list_param.append(param_seasonal)
print(min_aic,list_param)
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# 1314.5323994894927 [(0, 1, 1), (0, 1, 1, 12)]
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
mod =SARIMAX(em_series_month,
                                order=(5, 0, 1),
                                seasonal_order=(5, 0, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4717      1.196      0.394      0.693      -1.872       2.816
# ar.L2         -0.5157      2.408     -0.214      0.830      -5.236       4.204
# ar.L3          1.0458      1.655      0.632      0.527      -2.198       4.290
# ar.L4         -0.4395      1.883     -0.233      0.815      -4.130       3.251
# ar.L5          0.4222      1.627      0.260      0.795      -2.766       3.611
# ma.L1          0.8420      0.883      0.954      0.340      -0.888       2.572
# ar.S.L12       0.3177      3.398      0.094      0.926      -6.342       6.978
# ar.S.L24      -0.2410      0.818     -0.294      0.768      -1.845       1.363
# ar.S.L36       0.4695      1.554      0.302      0.763      -2.576       3.515
# ar.S.L48      -0.2676      1.302     -0.206      0.837      -2.820       2.284
# ar.S.L60       0.2250      1.222      0.184      0.854      -2.171       2.621
# ma.S.L12       0.0171      3.348      0.005      0.996      -6.545       6.579
# sigma2      1.198e+08   5.19e-08   2.31e+15      0.000     1.2e+08     1.2e+08
# ==============================================================================
# D:\Software\Anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
pred = results.get_prediction(start='2017-01', dynamic=False)
pred_ci = pred.conf_int()

ax = em_series_month['2017-01':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='forecast', color='red', alpha=.7, figsize=(14, 7))

# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Month')
ax.set_ylabel('revenue')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = em_series_month['2017-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted,)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# RMSE: 6652.027
# MAPE: 0.245

# %%
index = pd.to_datetime(['2020-01-01', '2020-02-01','2020-03-01','2020-02-01','2020-04-01','2020-05-01',
                        '2020-06-01','2020-07-01','2020-08-01','2020-09-01','2020-10-01','2020-11-01','2020-12-01',
                       '2021-01-01', '2021-02-01','2021-03-01','2021-02-01','2021-04-01','2021-05-01',
                        '2021-06-01','2021-07-01','2021-08-01','2021-09-01','2021-10-01','2021-11-01','2021-12-01'])
pred_uc = results.get_forecast(steps=len(index),index=index)
pred_ci = pred_uc.conf_int()
ax = em_series_month.plot(label='observed', figsize=(14, 7),)
pred_uc.predicted_mean.plot(ax=ax, label='forecast',color='red')
# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Month')
ax.set_ylabel('revenue')
plt.legend()
plt.show()

# %%
pred_uc.predicted_mean.to_frame()
# Out:
#             predicted_mean
# 2020-01-01    43473.051426
# 2020-02-01    22264.775423
# 2020-03-01    14525.981149
# 2020-02-01    43068.220792
# 2020-04-01    28860.905728
# 2020-05-01    20787.774300
# 2020-06-01    46774.336658
# 2020-07-01    22033.738186
# 2020-08-01    23602.785359
# 2020-09-01    51996.049064
# 2020-10-01    21333.285760
# 2020-11-01    14831.549692
# 2020-12-01    51004.741135
# 2021-01-01    29244.362344
# 2021-02-01    10696.922782
# 2021-03-01    46520.599315
# 2021-02-01    27678.601560
# 2021-04-01    13379.289525
# 2021-05-01    42020.371497
# 2021-06-01    37060.744828
# 2021-07-01    16501.174631
# 2021-08-01    37556.475365
# 2021-09-01    31350.168387
# 2021-10-01    20441.004315
# 2021-11-01    42622.702022
# 2021-12-01    31410.602849

# %%
mod =SARIMAX(em_series_year,
                                order=(1, 0, 0),
                                seasonal_order=(1, 0, 1, 2),
#                                 order=(1, 0, 1),
#                                 seasonal_order=(0, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.3688      2.640     -0.518      0.604      -6.543       3.805
# ar.S.L2        0.5840      0.472      1.236      0.216      -0.342       1.510
# ma.S.L2        1.2748      0.373      3.419      0.001       0.544       2.006
# sigma2      1.752e+10   4.99e-11   3.51e+20      0.000    1.75e+10    1.75e+10
# ==============================================================================
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'

# %%
pred = results.get_prediction(start='2014-01-01', dynamic=False)
pred_ci = pred.conf_int()

ax = em_series_year['2014-01':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='forecast', color='red', alpha=.7, figsize=(14, 7))

# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Year')
ax.set_ylabel('revenue')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = em_series_year['2014-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted,)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# RMSE: 63388.864
# MAPE: 0.305

# %%
index = pd.to_datetime(['2019', '2020','2021','2022'])
pred_uc = results.get_forecast(steps=len(index),index=index)
pred_ci = pred_uc.conf_int()
ax = em_series_year.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='forecast',color='red')
# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Year')
ax.set_ylabel('revenue')
plt.legend()
plt.show()

# %%
pred_uc.predicted_mean.to_frame()
# Out:
#             predicted_mean
# 2019-01-01   -3.520534e+05
# 2020-01-01    8.436314e+05
# 2021-01-01   -1.088118e+06
# 2022-01-01    1.700701e+06
# 2023-01-01   -2.289029e+06

# %% [markdown]
# # Engine Model L13A

# %%
df_sum_day = df_fp.groupby(['Register Date'])['total_price'].sum().reset_index()
df_sum_month = df_fp.groupby(['month_year'])['total_price'].sum().reset_index()
df_sum_year = df_fp.groupby(['year'])['total_price'].sum().reset_index()
df_sum_month['month_year'] = pd.to_datetime(df_sum_month['month_year'],format='%Y-%m')
df_sum_month.set_index('month_year',inplace = True)
# df_sum_day['Register Date'] = df_sum_day['Register Date'].astype(str)
df_sum_year['year'] = pd.to_datetime(df_sum_year['year'],format='%Y')
em_series_month =  pd.Series(df_sum_month.total_price.values,index=df_sum_month.index)
em_series_year =  pd.Series(df_sum_year.total_price.values,index=df_sum_year['year'])
em_series = pd.Series(df_sum_day.total_price.values,index=df_sum_day['Register Date'])
em_series_sample = pd.Series(df_fp.total_price.values,index=df_fp['Register Date'])

# %%
decomposition = seasonal_decompose(em_series_month, model='additive',period = 2)
plt.figure(figsize=(12,8))
plt.xticks(fontsize = 20, rotation = 0)
plt.yticks(fontsize = 20, rotation = 0)
plt.xlabel('Year',fontsize = 20)
plt.ylabel('value',fontsize = 20)
plt.plot(decomposition.trend)

# %%
X = np.log(em_series_month).values
size = int(len(X) * 0.75)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,0,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))
# evaluate forecasts
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)
rmse = mean_squared_error(np.exp(test), np.exp(predictions),squared=False)
mape = mean_absolute_percentage_error(np.exp(test), np.exp(predictions))
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# predicted=25285.821398, expected=8093.870000
# predicted=15109.933865, expected=22646.390000
# predicted=21633.801000, expected=32879.420000
# predicted=25812.825692, expected=56744.130000
# predicted=22470.761376, expected=46868.280000
# predicted=25665.894124, expected=48773.980000
# predicted=31097.053750, expected=47389.320000
# predicted=36782.748406, expected=33592.290000
# predicted=32470.688509, expected=21231.210000
# predicted=26375.385282, expected=43776.670000
# predicted=32640.362330, expected=45845.970000
# predicted=33554.051527, expected=15566.640000
# predicted=20324.420599, expected=30945.370000
# predicted=26397.076465, expected=35733.890000
# predicted=31237.793245, expected=20262.670000
# predicted=20910.882638, expected=20813.750000
# predicted=21954.550898, expected=39466.280000
# predicted=28674.760070, expected=46124.760000
# predicted=28368.721068, expected=15926.540000
# predicted=20202.308835, expected=65221.450000
# predicted=33507.482824, expected=59556.540000
# predicted=38074.443693, expected=28359.860000
# RMSE: 18651.761
# MAPE: 0.517

# %%
df_sum_month.reset_index(inplace=True)
df_sum_month['month_year'] = df_sum_month['month_year'].astype(str)
list_datetime = list(df_sum_month['month_year'][size:len(X)])
plt.figure(figsize=(12,8))
plt.plot(np.exp(predictions), color='red')
plt.xticks(rotation = 90)
plt.xlabel('Month')
plt.ylabel('revenue')
sns.lineplot(x=list_datetime,y='total_price',data=df_sum_month[size:len(X)])
plt.legend(loc='upper left', labels=['forecast','test'])

# %%
mod =SARIMAX(em_series_month,
                                order=(5, 0, 1),
                                seasonal_order=(5, 0, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1624      2.412      0.067      0.946      -4.566       4.891
# ar.L2          0.1193      0.434      0.275      0.783      -0.732       0.970
# ar.L3          0.4841      0.401      1.206      0.228      -0.302       1.271
# ar.L4          0.5881      1.103      0.533      0.594      -1.573       2.749
# ar.L5         -0.3539      1.720     -0.206      0.837      -3.725       3.018
# ma.L1         -0.0235      2.986     -0.008      0.994      -5.876       5.829
# ar.S.L12      -0.5284      5.151     -0.103      0.918     -10.625       9.568
# ar.S.L24       0.0498      0.875      0.057      0.955      -1.665       1.765
# ar.S.L36      -0.3063      0.447     -0.686      0.493      -1.182       0.569
# ar.S.L48      -0.5724      1.474     -0.388      0.698      -3.462       2.317
# ar.S.L60       0.1558      2.318      0.067      0.946      -4.387       4.698
# ma.S.L12       0.6486      4.881      0.133      0.894      -8.918      10.215
# sigma2      2.403e+08   2.72e-08   8.82e+15      0.000     2.4e+08     2.4e+08
# ==============================================================================

# %%
pred = results.get_prediction(start='2017-01', dynamic=False)
pred_ci = pred.conf_int()

ax = em_series_month['2017-01':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='forecast', color='red', alpha=.7, figsize=(14, 7))

# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Month')
ax.set_ylabel('revenue')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = em_series_month['2017-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted,)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# RMSE: 12012.690
# MAPE: 0.272

# %%
index = pd.to_datetime(['2020-01-01', '2020-02-01','2020-03-01','2020-02-01','2020-04-01','2020-05-01',
                        '2020-06-01','2020-07-01','2020-08-01','2020-09-01','2020-10-01','2020-11-01','2020-12-01',
                       '2021-01-01', '2021-02-01','2021-03-01','2021-02-01','2021-04-01','2021-05-01',
                        '2021-06-01','2021-07-01','2021-08-01','2021-09-01','2021-10-01','2021-11-01','2021-12-01'])
pred_uc = results.get_forecast(steps=len(index),index=index)
pred_ci = pred_uc.conf_int()
ax = em_series_month.plot(label='observed', figsize=(14, 7),)
pred_uc.predicted_mean.plot(ax=ax, label='forecast',color='red')
# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Month')
ax.set_ylabel('revenue')
plt.legend()
plt.show()

# %%
pred_uc.predicted_mean.to_frame()
# Out:
#             predicted_mean
# 2020-01-01    45994.305185
# 2020-02-01    81089.067285
# 2020-03-01    49548.869597
# 2020-02-01    53017.254209
# 2020-04-01    40273.764865
# 2020-05-01    70121.300907
# 2020-06-01    42797.744352
# 2020-07-01    51003.165224
# 2020-08-01    59885.910745
# 2020-09-01    47199.670346
# 2020-10-01    18563.748971
# 2020-11-01    38126.856906
# 2020-12-01    45480.258355
# 2021-01-01    33005.759214
# 2021-02-01    43665.483736
# 2021-03-01    40601.758088
# 2021-02-01    56800.488567
# 2021-04-01    23149.242684
# 2021-05-01    38159.491263
# 2021-06-01    38548.341808
# 2021-07-01    25419.981504
# 2021-08-01    39378.054008
# 2021-09-01    57587.150055
# 2021-10-01    48779.217011
# 2021-11-01    20868.977210
# 2021-12-01    43609.106761

# %%
mod =SARIMAX(em_series_year,
#                                 order=(1, 0, 1),
#                                 seasonal_order=(0, 0, 0, 12),
                                order=(1, 0, 0),
                                seasonal_order=(1, 0, 1, 2),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0234      0.680      1.506      0.132      -0.308       2.355
# ar.S.L2        1.1281      1.265      0.892      0.372      -1.351       3.607
# ma.S.L2       -3.7190     20.379     -0.182      0.855     -43.662      36.224
# sigma2      3.765e+10   3.69e-10   1.02e+20      0.000    3.77e+10    3.77e+10
# ==============================================================================
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'
# D:\Software\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   warnings.warn('No frequency information was'

# %%
pred = results.get_prediction(start='2014-01-01', dynamic=False)
pred_ci = pred.conf_int()

ax = em_series_year['2014-01':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='forecast', color='red', alpha=.7, figsize=(14, 7))

# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Year')
ax.set_ylabel('revenue')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = em_series_year['2014-01-01':]
rmse = mean_squared_error(y_truth, y_forecasted,squared=False)
mape = mean_absolute_percentage_error(y_truth, y_forecasted,)
print('RMSE: %.3f' % rmse)
print('MAPE: %.3f' % mape)
# Out:
# RMSE: 52312.640
# MAPE: 0.219

# %%
index = pd.to_datetime(['2019', '2020','2021','2022','2023'])
pred_uc = results.get_forecast(steps=len(index),index=index)
pred_ci = pred_uc.conf_int()
ax = em_series_year.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='forecast',color='red')
# ax.fill_between(pred_ci.index,
#                 pred_ci.iloc[:, 0],
#                 pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Year')
ax.set_ylabel('revenue')
plt.legend()
plt.show()

# %%
pred_uc.predicted_mean.to_frame()
# Out:
#             predicted_mean
# 2019-01-01   181618.865701
# 2020-01-01   523682.558516
# 2021-01-01   251515.423565
# 2022-01-01   638488.331049
# 2023-01-01   332571.012044
