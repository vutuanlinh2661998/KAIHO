# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import re
import itertools
from itertools import chain
import glob

# %%
s = 'E07A-series'
s1 = re.findall(r"\b[A-Z][0-9]+\w+\b",s)
# s1 = re.findall("^((.*[0-9]+)[A-Z]+.*)|((.*[A-Z]+)[0-9]+.*)$",s)
s1
# Out:
# ['E07A']

# %%
list_honda = pd.read_excel('honda_list_engine.xlsx')
list_honda.head()
# Out:
#                   List engines model
# 0            Inline 2-cylinder[edit]
# 1  EH：1977–1988 Acty:1985–1988 Today
# 2            Inline 3-cylinder[edit]
# 3                        E07A-series
# 4                00–06 ECA1 (hybrid)

# %%
list_honda['Engine_Famlily']  = list_honda['List engines model'].str.extract(r"(\b[A-Z][A-Z0-9]+\w+\b)",expand=True)

# %%
list_honda
# Out:
#                     List engines model Engine_Famlily
# 0              Inline 2-cylinder[edit]            NaN
# 1    EH：1977–1988 Acty:1985–1988 Today            NaN
# 2              Inline 3-cylinder[edit]            NaN
# 3                          E07A-series           E07A
# 4                  00–06 ECA1 (hybrid)           ECA1
# ..                                 ...            ...
# 315             1966/1967 3.0 L RA273E         RA273E
# 316             1967/1968 3.0 L RA273E         RA273E
# 317                  1968 3.0 L RA273E         RA273E
# 318                  1991 3.5 L RA121E         RA121E
# 319                1992 3.5 L RA122E/B         RA122E
#
# [320 rows x 2 columns]

# %%
list_honda.isnull().sum()
# Out:
# List engines model     0
# Engine_Famlily        37
# dtype: int64

# %%
list_honda.to_excel('list_honda.xlsx')

# %%
df = pd.read_excel('list_honda.xlsx')
df.dropna(inplace=True)

# %%
df.drop(columns = ['Unnamed: 0'],inplace=True)

# %%
df.reset_index().drop(columns=['index'],inplace=True)

# %%
df.drop(columns=['List engines model'],inplace=True)

# %%
all_data = pd.DataFrame()
for f in glob.glob("C://Users//XPS 15 9560//Github//GTO_Data//GTO_Data_Full//840734//*.xls"):
    df = pd.read_excel(f,sheet_name=1)
    all_data = all_data.append(df,ignore_index=True)

all_data.to_excel("list_all_em_GTO.xlsx")

# %%
df_em = pd.read_excel('list_all_em_GTO.xlsx')
df_em
# Out:
#         Unnamed: 0 Register Date     HS Code  \
# 0                0    2011-01-29  8407349908
# 1                1    2011-01-29  8407349908
# 2                2    2011-01-17  8407343009
# 3                3    2011-01-17  8407343009
# 4                4    2011-01-20  8407343009
# ...            ...           ...         ...
# 259191      259191    2019-12-01  8407349908
# 259192      259192    2019-12-01  8407349908
# 259193      259193    2019-12-01  8407349908
# 259194      259194    2019-12-01  8407349908
# 259195      259195    2019-12-01  8407349908
#
#                                       Product Description  \
# 0       СИЛОВОЙ АГРЕГАТ TOYOTA 2TR-FE-261 В РАЗОБРАННО...
# 1       СИЛОВОЙ АГРЕГАТ TOYOTA 2TR-FE-A343E-111 В РАЗО...
# 2       ДВИГАТЕЛЬ ЗИЛ ,Б/У,БЕНЗИНОВЫЙ,ОБЪЕМ 6000СМ.КУБ...
# 3       ДВИГАТЕЛЬ ЗИЛ ,Б/У,НЕКОМПЛЕКТНЫЙ,БЕНЗИНОВЫЙ,ОБ...
# 4       ДВИГАТЕЛИ БЕНЗИНОВЫЕ В СБОРЕ С КОРОБКОЙ ПЕРЕДА...
# ...                                                   ...
# ...

# %%
df_em.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df_em.fillna(value='Unknown',inplace=True)

# %%
df_em.nunique()
# Out:
# Register Date            2090
# HS Code                     7
# Product Description    130541
# Producer                11463
# Brand                    4510
# Place of Receipt          657
# Country of Origin          98
# Country of Sales          108
# Shipper                  5519
# Shipper Address         11962
# Consignee                2614
# Consignee Address        5079
# Quantity                  737
# Unit of Measure             2
# Incoterms                  15
# Gross Weight in KG      34453
# Net Weight in KG        25997
# Cargo Value USD        149639
# dtype: int64

# %%
df_em.isnull().sum()
# Out:
# Register Date               0
# HS Code                     0
# Product Description        38
# Producer                  853
# Brand                   56229
# Place of Receipt         3133
# Country of Origin         752
# Country of Sales         3250
# Shipper                   301
# Shipper Address         30828
# Consignee                  67
# Consignee Address        6020
# Quantity                    0
# Unit of Measure        108466
# Incoterms                2234
# Gross Weight in KG          0
# Net Weight in KG            0
# Cargo Value USD             0
# dtype: int64

# %%
s = 'ДВИГАТЕЛЬ БЕНЗИНОВЫЙ БЫВ.В УПОТР. В СБОРЕ С КОР.ПЕРЕДАЧ,ДЛЯ Л/А,ОБЪЕМ 1300-4000CC-41 ШТ TOYOTA: 5E-0232903;5E-0703072;3S-9334004;7A-G289748;7A-J087647;1UZ-0101881;2JZ-0877113;2JZ-1081736;1JZ-6078881;5A-H335743; 4A-M508250; NISSAN: QG18-370972;SR20-05'
type(s)
# Out:
# str

# %%
# list_toyota = pd.read_excel('em_toyota.xlsx')
list_toyota['List engine'].str.strip()
for e in list_toyota['List engine'].tolist():
    df_em['Engine Model'] = df_em['Product Description'].str.extract(r"(\b{}-\w+\S+\b)".format(e),expand=True)

# %%
df_em['Engine Model'] = df_em['Product Description'].str.extract(r"(\b{}-\w+\S+\b)".format('2TR'),expand=True)

# %%
df_em['Engine Model'].isnull().sum()
# Out:
# 259105

# %%
df_em['Engine Model']
# Out:
# 0               2TR-FE-261
# 1         2TR-FE-A343E-111
# 2                      NaN
# 3                      NaN
# 4                      NaN
#                 ...
# 259191                 NaN
# 259192                 NaN
# 259193                 NaN
# 259194                 NaN
# 259195                 NaN
# Name: Engine Model, Length: 259196, dtype: object

# %%
e='2JZ'
r = re.search(r"(\b{}-\w+\b)".format(e),s)
r.group()
# Out:
# '2JZ-0877113'

# %%
df_em['Engine Model'].to_excel('test.xlsx')

# %%
s = 'СИЛОВОЙ АГРЕГАТ TOYOTA 2TR-FE-261 В РАЗОБРАННОМ ВИДЕ ПРЕДСТАВЛЯЕТ СОБОЙ КОМПЛЕКТ ДВИГАТЕЛЯ БЕЗ КОРОБКИ ПЕРЕДАЧ БЕНЗИНОВОГО ВНУТРЕННЕГО СГОРАНИЯ TOYOTA МАРКИ 2TR-FE С ИСКРОВЫМ ЗАЖИГАНИЕМ С ВОЗВРАТНО-ПОСТУПАТЕЛЬНЫМ ДВИЖЕНИЕМ ПОРШНЯ'

# %%
# df_2011 = pd.read_excel('C://Users//Admin//JupiterProject//Data//GTO//GTO_Data_Full//840734//Russia-840734-2011.xls',sheet_name=1)
df_2011 = pd.read_excel('C://Users//XPS 15 9560//Github//GTO_Data//GTO_Data_Full//840734//Russia-840734-2011.xls',sheet_name=1)

# %%
df_2011.isnull().sum()
# Out:
# Register Date             0
# HS Code                   0
# Product Description      14
# Producer                 56
# Brand                    91
# Place of Receipt         57
# Country of Origin         0
# Country of Sales          0
# Shipper                  73
# Shipper Address         571
# Consignee                 0
# Consignee Address         0
# Quantity                  0
# Unit of Measure           1
# Incoterms              1242
# Gross Weight in KG        0
# Net Weight in KG          0
# Cargo Value USD           0
# dtype: int64

# %%
df_2011.fillna(value='Unknown',inplace=True)

# %%
list_toyota = pd.read_excel('em_toyota.xlsx')

# %%
def extract_engine_model (description, list_em = list_toyota['List engine'].str.strip().tolist()):
    engine_model = []
    for e in list_em:
        em_reg1 = re.findall(r"(\b{}-\w+\b)".format(e), description)
        em_reg2 = re.findall(r"(\b{}-\w+-\w+\b)".format(e), description)
        if len(em_reg1) != 0 :
          em_reg1 = list(set(em_reg1)) 
          engine_model.append(em_reg1)
        if len(em_reg2) != 0 :
          em_reg2 = list(set(em_reg2))
          engine_model.append(em_reg2)
    
    return list(chain(*engine_model))
#     return engine_model

# %%
extract_engine_model(s,list_toyota['List engine'].str.strip().tolist())
# Out:
# ['2TR-FE', '2TR-FE-261']

# %%
df_2011['toyota_em']  = df_2011['Product Description'].apply(extract_engine_model)

# %%
df_2011['toyota_em']
# Out:
# 0          [2TR-FE, 2TR-FE-261]
# 1        [2TR-FE, 2TR-FE-A343E]
# 2                            []
# 3                            []
# 4                            []
#                   ...
# 20802                        []
# 20803                        []
# 20804                        []
# 20805                        []
# 20806                        []
# Name: toyota_em, Length: 20807, dtype: object

# %%
df_em['toyota_em']  = df_em['Product Description'].apply(extract_engine_model)

# %%
df_em['toyota_em']
# Out:
# 0           [2TR-FE, 2TR-FE-261]
# 1         [2TR-FE, 2TR-FE-A343E]
# 2                             []
# 3                             []
# 4                             []
#                    ...
# 259191                        []
# 259192                        []
# 259193                        []
# 259194                        []
# 259195                        []
# Name: toyota_em, Length: 259196, dtype: object

# %%
list_all_engine_model = []

for des in df_2011['Product Description'].tolist():
#     print(type(des))
    list_em = extract_engine_model(des,list_toyota['List engine'].str.strip().tolist())
    if len(list_em) !=0:
      list_all_engine_model.append(list_em)
    
list_all_engine_model
# Out:
# [['2TR-FE', '2TR-FE-261'],
#  ['2TR-FE', '2TR-FE-A343E'],
#  ['1JZ-0649357'],
#  ['5K-1298931', '2TR-0221092', '2UZ-9064542'],
#  ['5K-1298931', '2TR-0221092', '2UZ-9064542'],
#  ['5VZ-0799452', '5VZ-0970651'],
#  ['1FZ-0331710', '5VZ-1157742', '5VZ-0818405'],
#  ['3S-7968456'],
#  ['1G-5897371'],
#  ['3F-0309291'],
#  ['1JZ-6116172', '1JZ-6119500', 'V-2491'],
#  ['5S-0922401', '1ZZ-0972897', '1ZZ-1052247', '1G-6613201'],
#  ['1NZ-B366087', '1NZ-A946272'],
#  ['3S-7051240', '2TZ-1423316', '1JZ-1423316'],
#  ['3S-1303230', '3S-7306959', '3S-6911045', '4S-1424182', '1NZ-2618515'],
#  ['2JZ-0299325'],
#  ['1MZ-0819394', '2UZ-0076639', '2UZ-0620456', '2UZ-0024244', '2UZ-0012648'],
#  ['5A-G855525', '3S-7526819', '4S-1329002', '4E-2277208', '5E-1403456'],
#  ['3S-9278941'],
#  ['5VZ-1213852', '2UZ-0005297', '2UZ-9003553'],
#  ['1ZZ-0399079', '2NZ-2404695', '1MZ-0762158'],
#  ['3S-9192911'],
#  ['1NZ-B000831', '1JZ-0523462', '1MZ-0792353'],
#  ['1NZ-A372882', '1AZ-4016158'],
# ...

# %%
len(list_all_engine_model)
# Out:
# 1586

# %%
list_all_engine_model_GTO = []

for des in df_em['Product Description'].tolist():
#     print(type(des))
    list_em = extract_engine_model(des,list_toyota['List engine'].str.strip().tolist())
    if len(list_em) !=0:
      list_all_engine_model_GTO.append(list_em)
    
list_all_engine_model_GTO
# Out:
# [['2TR-FE', '2TR-FE-261'],
#  ['2TR-FE', '2TR-FE-A343E'],
#  ['1JZ-0649357'],
#  ['5K-1298931', '2TR-0221092', '2UZ-9064542'],
#  ['5K-1298931', '2TR-0221092', '2UZ-9064542'],
#  ['5VZ-0970651', '5VZ-0799452'],
#  ['1FZ-0331710', '5VZ-0818405', '5VZ-1157742'],
#  ['3S-7968456'],
#  ['1G-5897371'],
#  ['3F-0309291'],
#  ['1JZ-6119500', '1JZ-6116172', 'V-2491'],
#  ['5S-0922401', '1ZZ-1052247', '1ZZ-0972897', '1G-6613201'],
#  ['1NZ-B366087', '1NZ-A946272'],
#  ['3S-7051240', '2TZ-1423316', '1JZ-1423316'],
#  ['3S-6911045', '3S-1303230', '3S-7306959', '4S-1424182', '1NZ-2618515'],
#  ['2JZ-0299325'],
#  ['1MZ-0819394', '2UZ-0076639', '2UZ-0012648', '2UZ-0024244', '2UZ-0620456'],
#  ['5A-G855525', '3S-7526819', '4S-1329002', '4E-2277208', '5E-1403456'],
#  ['3S-9278941'],
#  ['5VZ-1213852', '2UZ-0005297', '2UZ-9003553'],
#  ['1ZZ-0399079', '2NZ-2404695', '1MZ-0762158'],
#  ['3S-9192911'],
#  ['1NZ-B000831', '1JZ-0523462', '1MZ-0792353'],
#  ['1NZ-A372882', '1AZ-4016158'],
# ...

# %%
from itertools import chain
x = [["a","b"], ["c"]]
y = list(chain(*x))

# %%
y
# Out:
# ['a', 'b', 'c']

# %%
l1 = [[1, 2],[3,4]]
l2 = [[5, 6],[7,8]]
l3 =[]
for (item1, item2) in zip(l1, l2):
    l3.append(item1 + item2)
l3
# Out:
# [[1, 2, 5, 6], [3, 4, 7, 8]]

# %%
list_mitsu = pd.read_excel('Book2.xlsx')
list_mitsu.head()
# Out:
#                                     List engine name
# 0  A-series — A 744 cc air-cooled OHV engine inst...
# 1  1952-196? — ME10/12 — A development of the A f...
# 2  As fitted to the 1.25-tonne (2,760 lb) Mitsubi...
# 3  NE/NE1 — "Nagoya Engine," First introduced as ...
# 4  ME20 — This 309 cc water-cooled OHV engine ser...

# %%
list_mitsu['List engine']  = list_mitsu['List engine name'].str.extract(r"(\b[0-9]?[A-Z]+[0-9]+)",expand=True)

# %%
list_mitsu['List engine']

# %%
list_mitsu['List engine'].to_excel('em_mitsubishi.xlsx')

# %%
df_list_engine = pd.read_excel('C:\\Users\\Admin\\Github\\Kaiho\\Engine Model _1025.xlsx')
df_list_engine.head()
# Out:
#    Unnamed: 0    メーカー   燃料 買付受付   型式 駆動1 駆動2  駆動3   詳細 車輌型式 KRA売単価   車名  仕入値  \
# 0         2.0    FIAT    0    ×    4  FR  AT  2WD  NaN  NaN    NaN  NaN  NaN
# 1         3.0  PORCHE  NaN    ×   64  RR  AT  4WD  NaN  NaN    NaN  NaN  NaN
# 2         4.0  PORCHE  NaN    ×   66  RR  MT  2WD  NaN  NaN    NaN  NaN  NaN
# 3         5.0  PORCHE  NaN    ×   70  RR  AT  4WD  NaN  NaN    NaN  NaN  NaN
# 4         6.0    BENZ  NaN    ○  102  FR  AT  2WD  NaN  NaN    NaN  NaN  NaN
#
#   EG売価\n（マニ触付）\nW EG売価\n（マニ触抜/無）\nWO
# 0            売価確認               売価確認
# 1            売価確認                  0
# 2            売価確認                  0
# 3            売価確認                  0
# 4           40000                  0

# %%
df_count_brand = df_list_engine.groupby(['メーカー'])['型式'].nunique().reset_index(name='counts')
df_count_brand
# Out:
#                メーカー  counts
# 0        ALFA ROMEO       2
# 1              AUDI      52
# 2              BENZ      43
# 3               BMW      64
# 4         CHEVROLET      13
# 5          CHRYSLER      19
# 6           CITROEN      29
# 7          DAIHATSU      30
# 8              FIAT      41
# 9              FORD       1
# 10               GM       2
# 11             HINO      21
# 12            HONDA      48
# 13          HYUNDAI       7
# 14            ISUZU      40
# 15           JAGUAR      17
# 16        LANDROVER      11
# 17            LEXUS       1
# 18            MAZDA      62
# 19       MITSUBISHI      66
# 20  MITSUBISHI FUSO       1
# 21           NISSAN     122
# 22             OPEL      23
# 23          PEUGEOT      37
# 24          PONTIAC       1
# 25           PORCHE      11
# 26          RENAULT      20
# 27            ROVER      14
# 28             SAAB      11
# 29           SUBARU      11
# 30           SUZUKI      26
# 31           TOYOTA     163
# ...

# %%
df_count_brand_toyota =  df_list_engine[df_list_engine['メーカー']  == 'TOYOTA']

# %%
list_toyota = list(df_count_brand_toyota['型式'].unique())
list_toyota
# Out:
# ['12H-T',
#  '13B',
#  '13B-T',
#  '14B',
#  '14B-T',
#  '15B-F',
#  '15B-FNE',
#  '15B-FP',
#  '15B-FT',
#  '15B-FTE',
#  '1AZ-FE',
#  '1AZ-FSE',
#  '1B',
#  '1BZ-FPE',
#  '1C',
#  '1FZ-FE',
#  '1G-E',
#  '1G-FE',
#  '1G-GE',
#  '1G-GEU',
#  '1G-GPE',
#  '1G-GTEU',
#  '1G-GZE',
#  '1GR-FE',
#  '1GZ-FE',
#  '1HD-FT',
#  '1HD-FTE',
#  '1HD-T',
#  '1HZ',
#  '1HZ-T',
#  '1JZ-FSE',
#  '1JZ-GE',
#  '1JZ-GTE',
#  '1KD-FTV',
#  '1KR-FE',
#  '1KR-VET',
#  '1KZ-TE',
#  '1MZ-FE',
#  '1N',
#  '1N-T',
#  '1ND-TV',
#  '1NR-FE',
#  '1NR-FKE',
#  '1NZ-FE',
#  '1NZ-FNE',
#  '1NZ-FXE',
#  '1PZ',
#  '1RZ',
#  '1RZ-E',
#  '1S-ELU',
#  '1SZ-FE',
#  '1TR-FE',
#  '1TR-FPE',
#  '1UR-FSE',
#  '1UZ-FE',
#  '1ZZ-FE',
#  '2AR-FE',
#  '2AR-FSE',
#  '2AR-FXE',
#  '2AZ-FE',
#  '2AZ-FSE',
#  '2AZ-FXE',
#  '2C',
#  '2C-T',
#  '2GR-FE',
#  '2GR-FKS',
#  '2GR-FSE',
#  '2GR-FXE',
#  '2GR-FXS',
#  '2H',
#  '2JZ-FSE',
#  '2JZ-GE',
#  '2JZ-GTE',
#  '2KD-FTV',
#  '2L',
#  '2L-II',
#  '2LII-TE',
#  '2LⅡ-TE',
#  '2MZ-FE',
# ...
