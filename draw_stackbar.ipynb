# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_GTO_miss_extract_famlily = pd.DataFrame(columns=["Brand","Extracted", "Non-Extracted"], data=[['TOYOTA', 38.62,61.38], ['MAZDA',32.15,67.85], ['MITSUBISHI',31.37,68.63], ['HONDA',38.11,61.89], ['NISSAN', 2.54, 98.46], ['SUBARU', 34.61, 68.39]])
df_JP_miss_extract_famlily = pd.DataFrame(columns=["Brand","Extracted", "Non-Extracted"], data=[['TOYOTA', 1.6,98.4], ['MAZDA',13.11,86.89], ['MITSUBISHI',35.47,64.53], ['HONDA',41.17,58.83], ['NISSAN', 3.79, 96.21], ['SUBARU', 38.9, 61.1]])
df_Kaiho_miss_extract_famlily = pd.DataFrame(columns=["Brand","Extracted", "Non-Extracted"], data=[['TOYOTA', 2.93,97.07], ['MAZDA',2.23,97.77], ['MITSUBISHI',3.64,96.36], ['HONDA',8.33,91.67], ['NISSAN', 4.37, 95.63], ['SUBARU', 20.8, 79.2]])

# %%
df_GTO_miss = pd.DataFrame(columns=["Brand","Extracted", "Non-Extracted"], data=[['TOYOTA', 38.62,61.38], ['MAZDA',32.14,67.86], ['MITSUBISHI',31.37,68.63], ['HONDA',38.11,61.89], ['NISSAN', 2.54, 98.46], ['SUBARU', 34.61, 68.39]])
df_JP_miss = pd.DataFrame(columns=["Brand","Extracted", "Non-Extracted"], data=[['TOYOTA', 39.5,60.5], ['MAZDA',35.81,64.19], ['MITSUBISHI',35.47,64.53], ['HONDA',41.17,58.83], ['NISSAN', 3.79, 96.21], ['SUBARU', 38.9, 61.1]])
df_Kaiho_miss = pd.DataFrame(columns=["Brand","Extracted", "Non-Extracted"], data=[['TOYOTA', 33.28,66.72], ['MAZDA',40.18,59.82], ['MITSUBISHI',3.64,96.36], ['HONDA',8.33,91.67], ['NISSAN', 4.37, 95.63], ['SUBARU', 20.8, 79.2]])

# %%
plt.style.use('ggplot')

ax = df_Kaiho_miss.set_index('Brand').plot(stacked=True, kind='bar', figsize=(12, 8), rot='horizontal')

# .patches is everything inside of the chart
for rect in ax.patches:
    # Find where everything is located
    height = rect.get_height()
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    
    # The height of the bar is the data value and can be used as the label
    label_text = f'{height:.2f}'  # f'{height:.2f}' to format decimal values
    
    # ax.text(x, y, text)
    label_x = round(x + width / 2,2)
    label_y = round(y + height / 2,2)

    # plot only when height is greater than specified value
    if height > 0:
        ax.text(label_x, label_y, label_text, ha='center', va='center', fontsize=10)
    
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)    
ax.set_ylabel("percent_value", fontsize=10)
ax.set_xlabel("Brand", fontsize=10)
plt.show()

# %%
plt.style.use('ggplot')

ax = df_GTO_miss_extract_famlily.set_index('Brand').plot(stacked=True, kind='bar', figsize=(12, 8), rot='horizontal')

# .patches is everything inside of the chart
for rect in ax.patches:
    # Find where everything is located
    height = rect.get_height()
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    
    # The height of the bar is the data value and can be used as the label
    label_text = f'{height}'  # f'{height:.2f}' to format decimal values
    
    # ax.text(x, y, text)
    label_x = round(x + width / 2,2)
    label_y = round(y + height / 2,2)

    # plot only when height is greater than specified value
    if height > 0:
        ax.text(label_x, label_y, label_text, ha='center', va='center', fontsize=8)
    
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)    
ax.set_ylabel("percent_value", fontsize=10)
ax.set_xlabel("Brand", fontsize=10)
plt.show()
